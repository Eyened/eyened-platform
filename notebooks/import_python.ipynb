# %%
from pathlib import Path
from tqdm.notebook import tqdm

# Import the Importer class
from eyened_orm.importer.importer import Importer
from eyened_orm.importer.importer_dtos import PatientImport, StudyImport, SeriesImport, ImageImport
from eyened_orm import Database
from eyened_orm.utils.config import load_config

# from rtnls_fundusprep.preprocessor import FundusPreprocessor
# from rtnls_fundusprep.utils import preprocess_for_inference
from tqdm.notebook import tqdm

# %%
config = load_config('/home/jose/vessels/eyened_platform/dev/.env')
session = Database(config).create_session()

# %%
# Set up project information
project_name = "FAU Fundus Dataset"

# %%
extract_dir = Path("/mnt/oogergo/eyened/public_data/av_segmentation/HRF_AV")

# %%
# Get all image paths
images_dir = extract_dir / "images"
image_paths = list(images_dir.glob("*"))

print(f"Found {len(image_paths)} images.")
# Out:
# Found 45 images.

# %%
# The dataset has images named as g0001.jpg, g0002.jpg, etc.
# Let's group images together in batches to demonstrate the hierarchy

# Create the data structure for the Importer
# Even though in this dataset each image is of a different patient
# We'll create one "patient" for every 10 images as an example
from datetime import date


data = []
batch_size = 10

for i in range(0, len(image_paths), batch_size):
    batch_images = image_paths[i : i + batch_size]

    # Create image objects
    images = []
    for img_path in batch_images:
        images.append(ImageImport(
            image=str(img_path.absolute()),
            old_path=img_path.stem
        ))
    
    # Create hierarchy objects
    series = SeriesImport(images=images)
    study = StudyImport(study_date=date.today(), series=[series])
    
    patient_item = PatientImport(
        project_name=project_name,
        patient_identifier=f"Patient_{i // batch_size + 1}",
        studies=[study]
    )

    data.append(patient_item)

print(f"Created data structure with {len(data)} patients.")
print(f"First patient has {len(data[0].studies[0].series[0].images)} images.")
# Out:
# Created data structure with 5 patients.
# First patient has 10 images.

# %% [markdown]
# ### Summaries
#
# The summary method will return a summary of created ORM objects without writing anything to the database

# %%
# We need to specify create_patients=True, create_studies=True
# since we're not providing identifiers
importer = Importer(
    session=session,
    config=config,
    create_projects=True,
    create_patients=True,
    create_studies=True,
    run_ai_models=False, 
    generate_thumbnails=True,
)

# Display a summary of what will be imported
import_summary = importer.import_many(data, summary=True)
# Out:
# Import Summary for Projects: FAU Fundus Dataset, FAU Fundus Dataset, FAU Fundus Dataset, FAU Fundus Dataset, FAU Fundus Dataset
# ----------------  Object Statistics  ----------------
#                Entity  Total  New  Existing New_Percentage Existing_Percentage
#              Patients      5    5         0         100.0%                0.0%
#               Studies      5    5         0         100.0%                0.0%
#                Series      5    5         0         100.0%                0.0%
#                Images     45   45         0         100.0%                0.0%
# Attribute_definitions      0    0         0           0.0%                0.0%
#      Attribute_values      0    0         0           0.0%                0.0%
#         Segmentations      0    0         0           0.0%                0.0%
#         Device_models      1    0         1           0.0%              100.0%
#      Device_instances      1    0         1           0.0%              100.0%
#
# -----------  Column Population Statistics  -----------
# - only for new entities
# - values set to NULL are not considered populated
#
# Populated Patients Columns:
#            Column  Populated Percentage
# PatientIdentifier          5     100.0%
#
# Populated Studies Columns:
#    Column  Populated Percentage
# StudyDate          5     100.0%
#
# Populated Images Columns:
#            Column  Populated Percentage
# DatasetIdentifier         45     100.0%
#           OldPath         45     100.0%
# /home/jose/vessels/eyened_platform/orm/eyened_orm/importer/importer.py:611: SAWarning: Object of type <ImageInstance> not in session, add operation along 'DeviceInstance.ImageInstances' will not proceed
#   with self.session.begin_nested():
# /home/jose/vessels/eyened_platform/orm/eyened_orm/importer/importer.py:611: SAWarning: Object of type <ImageInstance> not in session, add operation along 'SourceInfo.ImageInstances' will not proceed
#   with self.session.begin_nested():

# %%
# # Create the importer with default settings
# # Because none of the objects exist
# # We run into an error if we run with default settings: create_series=True, create_studies=False, create_patients=False
# importer = Importer(
#     session=session,
#     # project_name=project_name, # Removed as it is now passed in PatientImport
#     config=config,
#     run_ai_models=True, 
#     generate_thumbnails=True,
# )

# # Display a summary of what will be imported
# import_summary = importer.import_many(data, summary=True)

# %% [markdown]
# ### Execution
#
# Once satisfied with the summary, commit the import to the database with `importer.exec`
# There might still be Exceptions generated during import, in which case nothing will change in the DB and no files will be written.
#
# Post-insertion scripts will run after insertion for non-essential steps such as:
#
# - Thumbnail generation (highly recommended to run)
# - Running image preprocessing scripts (eg. CFI bounds detection)
# - Running AI models which populate DB columns
# - Hashing the files for error and duplicate checks

# %%
importer.import_many(data)
# Out:
# 100%|██████████| 45/45 [03:54<00:00,  5.21s/it]
# [ImageInstance(ImageInstanceID=2538861, SeriesID=2026925, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/15_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/9fc7b8e9ecf277ffa076176f, OldPath=15_g, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538862, SeriesID=2026925, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/05_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/b4e2224f9a001b046af2c71f, OldPath=05_h, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538863, SeriesID=2026925, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/15_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/4d2a2858885cf776eb799272, OldPath=15_h, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538864, SeriesID=2026925, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/06_dr.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/7a26e8427778ed69671e76ac, OldPath=06_dr, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538865, SeriesID=2026925, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/01_dr.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/f2adacf7e4fd2ed46109dfc2, OldPath=01_dr, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538866, SeriesID=2026925, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/10_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/958ee460596a1d1f2d068057, OldPath=10_g, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538867, SeriesID=2026925, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/12_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/f20d829aae40ddc6e0c3b890, OldPath=12_g, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538868, SeriesID=2026925, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/14_dr.JPG, AltDatasetIdentifier=None, ThumbnailPath=12040/bfaa95f666f59efdd198ac9a, OldPath=14_dr, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538869, SeriesID=2026925, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/15_dr.JPG, AltDatasetIdentifier=None, ThumbnailPath=12040/a3db27cb223da3b9043b4dcb, OldPath=15_dr, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538870, SeriesID=2026925, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/13_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040
SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/02_dr.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/068aeaad8e283743071fb0fa, OldPath=02_dr, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538898, SeriesID=2026928, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/11_dr.JPG, AltDatasetIdentifier=None, ThumbnailPath=12040/4f66681a08a6e8c00bdc61e6, OldPath=11_dr, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538899, SeriesID=2026928, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/13_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/b610300b0984aee9173acd69, OldPath=13_h, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538900, SeriesID=2026928, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/02_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/229e78f9904a98d977cce7b9, OldPath=02_g, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538901, SeriesID=2026929, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/08_dr.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/bc2b49a3fbae249cb18d2218, OldPath=08_dr, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538902, SeriesID=2026929, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/01_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/22d1ebeb665b1aabf47f4573, OldPath=01_g, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538903, SeriesID=2026929, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/06_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/1c1e42766bbd763d1ea99140, OldPath=06_h, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538904, SeriesID=2026929, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/07_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/8d8b064b785bb9f29a7c13f1, OldPath=07_g, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=2538905, SeriesID=2026929, SourceInfoID=37, DeviceInstanceID=59, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/04_dr.jpg, AltDatasetIdentifier=None, ThumbnailPath=12040/ac4c1ca61ac82b8cb7b49ea6, OldPath=04_dr, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, FileChecksum=None, DataHash=None, DateInserted=2025-11-23 21:36:28, DateModified=2025-11-23 21:40:23, DatePreprocessed=None)]

# %% [markdown]
# ### Inspect Results
#
# The project is now in the DB. We can easily generate a dataframe with image details to inspect results

# %%
# inspect the project using the ORM
from eyened_orm import Project


project = Project.by_name(session, 'FAU Fundus Dataset')

# %%
project.make_dataframe(session)

# %% [markdown]
# ### Updating existing projects
#
# Images can be inserted into existing projects, patients, studies and series by passing an existing project name, patient_identifier, study_date or series_id in the input structure. These will be matched to database entities (taking into account their nested structure).

# %%
# to simulate inserting into an existing project, we'll insert the same data again
# use create_patients=False, create_studies=False, create_series=False when inserting into existing objects to ensure that no new objects will be created
# copy_files=True will copy the files to a configurable directory
importer = Importer(
    session=session,
    config=config,
    run_ai_models=True, 
    generate_thumbnails=True,
    # copy_files=True # removed copy_files as it wasn't in __init__ signature I read
)

# Display a summary of what will be imported
import_summary = importer.import_many(data, summary=True)

# %%
importer.import_many(data)

# %%
project = Project.by_name(session, 'FAU Fundus Dataset')
project.make_dataframe(session)
