# %%
from pathlib import Path

from eyened_orm.importer.importer import Importer
from eyened_orm.importer.importer_dtos import PatientImport, StudyImport, SeriesImport, ImageImport
from eyened_orm import Database

# %%
from dotenv import load_dotenv
env_path = Path.cwd().parent.parent / ".env.dev"
load_dotenv(env_path)

session = Database().create_session()

# %%
# Set up project information
project_name = "FAU Fundus Dataset"
extract_dir = Path("/mnt/oogergo/eyened/public_data/av_segmentation/HRF_AV")
# Get all image paths
images_dir = extract_dir / "images"
image_paths = list(images_dir.glob("*"))

print(f"Found {len(image_paths)} images.")
# Out:
# Found 45 images.

# %%
storage_backends = {
    "/mnt/oogergo/": "oogergo",
}

def split_path(path):
    for key, value in storage_backends.items():
        if str(path).startswith(key):
            return value, str(path)[len(key) :]
    raise ValueError(f"Path {path} not found in storage backends")

def get_image_import(img_path):
    storage_backend_key, object_key = split_path(img_path)
    return ImageImport(object_key=object_key, storage_backend_key=storage_backend_key)

# %%
# The dataset has images named as g0001.jpg, g0002.jpg, etc.
# Let's group images together in batches to demonstrate the hierarchy

# Create the data structure for the Importer
# Even though in this dataset each image is of a different patient
# We'll create one "patient" for every 10 images as an example
from datetime import date


data = []
batch_size = 10

for i in range(0, len(image_paths), batch_size):
    batch_images = image_paths[i : i + batch_size]

    # Create image objects
    images = [get_image_import(img_path) for img_path in batch_images]

    # Create hierarchy objects
    series = SeriesImport(images=images)
    study = StudyImport(study_date=date.today(), series=[series])

    patient_item = PatientImport(
        project_name=project_name,
        patient_identifier=f"Patient_{i // batch_size + 1}",
        studies=[study],
    )

    data.append(patient_item)

print(f"Created data structure with {len(data)} patients.")
print(f"First patient has {len(data[0].studies[0].series[0].images)} images.")
# Out:
# Created data structure with 5 patients.
# First patient has 10 images.

# %% [markdown]
# ### Summaries
#
# The summary method will return a summary of created ORM objects without writing anything to the database

# %%
# We need to specify create_patients=True, create_studies=True
# since we're not providing identifiers
importer = Importer(
    session=session,
    create_projects=True,
    create_patients=True,
    create_studies=True,
    run_ai_models=False, 
    generate_thumbnails=True,
)

# Display a summary of what will be imported
import_summary = importer.import_many(data, summary=True)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/connections.py:575, in Connection.query(self, sql, unbuffered)
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/connections.py:826, in Connection._read_query_result(self, unbuffered)
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/connections.py:1203, in MySQLResult.read(self)
#    1202 try:
# -> 1203     first_packet = self.connection._read_packet()
#    1205     if first_packet.is_ok_packet():
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/connections.py:782, in Connection._read_packet(self, packet_type)
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry 'eyened/public_data/av_segmentation/HRF_AV/images/15_g.jpg-3' for key 'ImageStorage.ObjectKey_StorageBackendID_UNIQUE'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[6], line 13
#       3 importer = Importer(
#       4     session=session,
#       5     create_projects=True,
#    (...)
#       9     generate_thumbnails=True,
#      10 )
#      12 # Display a summary of what will be imported
# ---> 13 import_summary = importer.import_many(data, summary=True)
#
# File ~/eyened-platform/orm/eyened_orm/importer/importer.py:568, in Importer.import_many(self, data, summary)
#     566 try:
#     567     if summary:
# --> 568         return self._summary(data)
#     569     else:
#     570         return self._import(data)
#
# File ~/eyened-platform/orm/eyened_orm/importer/importer.py:469, in Importer._summary(self, data)
#     467 def _summary(self, data: List[PatientImport]) -> Dict:
#     468     with self.session.begin_nested():
# --> 469         self.init_objects(data)
#     471         classes = {e.__class__ for e in self._all_entities}
#     472         entities = {
#     473             c: [e for e in self._all_entities if isinstance(e, c)] for c in classes
#     474         }
#
# File ~/eyened-platform/orm/eyened_orm/importer/importer.py:163, in Importer.init_objects(self, data)
#     160 self.pending_segmentation_writes = []
#     162 for patient_item in data:
# --> 163     self._import_patient_tree(patient_item)
#
# File ~/eyened-platform/orm/eyened_orm/importer/importer.py:170, in Importer._import_patient_tree(self, patient_item)
#     167 patient = self._ensure_patient(project, patient_item)
#     169 for study_item in patient_item.studies:
# --> 170     self._import_study_tree(patient, study_item)
#
# File ~/eyened-platform/orm/eyened_orm/importer/importer.py:176, in Importer._import_study_tree(self, patient, study_item)
#     173 study = self._ensure_study(patient, study_item)
#     175 for series_item in study_item.series:
# --> 176     self._import_series_tree(study, series_item)
#
# File ~/eyened-platform/orm/eyened_orm/importer/importer.py:182, in Importer._import_series_tree(self, study, series_item)
#     179 series = self._ensure_series(study, series_item)
#     181 for image_item in series_item.images:
# --> 182     self._import_image(series, image_item)
#
# File ~/eyened-platform/orm/eyened_orm/importer/importer.py:185, in Importer._import_image(self, series, image_item)
#     184 def _import_image(self, series: Series, image_item: ImageImport):
# --> 185     image = self.create_image(series, image_item)
#     187     if image_item.attributes:
#     188         self._process_attributes(image, image_item.attributes)
#
# File ~/eyened-platform/orm/eyened_orm/importer/importer.py:408, in Importer.create_image(self, series, image_data)
#     400 image_storage = ImageStorage(
#     401     ImageInstance=im,
#     402     StorageBackend=storage_backend,
#    (...)
#     405     IsPrimary=True,
#     406 )
#     407 self.session.add(image_storage)
# --> 408 self.session.flush([image_storage])
#     409 self._track_entity_state(image_storage, is_new=True)
#     411 return im
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/orm/session.py:4331, in Session.flush(self, objects)
#    4329 try:
#    4330     self._flushing = True
# -> 4331     self._flush(objects)
#    4332 finally:
#    4333     self._flushing = False
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/orm/session.py:4466, in Session._flush(self, objects)
#    4463     transaction.commit()
#    4465 except:
# -> 4466     with util.safe_reraise():
#    4467         transaction.rollback(_capture_exception=True)
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/orm/session.py:4427, in Session._flush(self, objects)
#    4425 self._warn_on_events = True
#    4426 try:
# -> 4427     flush_context.execute()
#    4428 finally:
#    4429     self._warn_on_events = False
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/orm/unitofwork.py:466, in UOWTransaction.execute(self)
#     464 else:
#     465     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466         rec.execute(self)
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/orm/unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/orm/persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      81     update = _collect_update_commands(
#      82         uowtransaction, table, states_to_update
#      83     )
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)
#      90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)
#     119     ),
#     120 )
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/orm/persistence.py:1233, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1227     result = connection.execute(
#    1228         statement.values(value_params),
#    1229         params,
#    1230         execution_options=execution_options,
#    1231     )
#    1232 else:
# -> 1233     result = connection.execute(
#    1234         statement,
#    1235         params,
#    1236         execution_options=execution_options,
#    1237     )
#    1239 primary_key = result.inserted_primary_key
#    1240 if primary_key is None:
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/sql/elements.py:527, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     525     if TYPE_CHECKING:
#     526         assert isinstance(self, Executable)
# --> 527     return connection._execute_clauseelement(
#     528         self, distilled_params, execution_options
#     529     )
#     530 else:
#     531     raise exc.ObjectNotExecutableError(self)
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)
#    1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)
#    1660         ret,
#    1661     )
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2363, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2361 elif should_wrap:
#    2362     assert sqlalchemy_exception is not None
# -> 2363     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2364 else:
#    2365     assert exc_info[1] is not None
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File ~/.venvs/default/lib/python3.12/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/connections.py:575, in Connection.query(self, sql, unbuffered)
#     573     sql = sql.encode(self.encoding, "surrogateescape")
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/connections.py:826, in Connection._read_query_result(self, unbuffered)
#     824     result.init_unbuffered_query()
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#     828 if result.server_status is not None:
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/connections.py:1203, in MySQLResult.read(self)
#    1201 def read(self):
#    1202     try:
# -> 1203         first_packet = self.connection._read_packet()
#    1205         if first_packet.is_ok_packet():
#    1206             self._read_ok_packet(first_packet)
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/connections.py:782, in Connection._read_packet(self, packet_type)
#     780     if self._result is not None and self._result.unbuffered_active is True:
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~/.venvs/default/lib/python3.12/site-packages/pymysql/err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'eyened/public_data/av_segmentation/HRF_AV/images/15_g.jpg-3' for key 'ImageStorage.ObjectKey_StorageBackendID_UNIQUE'")
# [SQL: INSERT INTO `ImageStorage` (`ImageInstanceID`, `StorageBackendID`, `ObjectKey`, `Hash`, `Checksum`, `Format`, `IsPrimary`) VALUES (%(ImageInstanceID)s, %(StorageBackendID)s, %(ObjectKey)s, %(Hash)s, %(Checksum)s, %(Format)s, %(IsPrimary)s)]
# [parameters: {'ImageInstanceID': 136, 'StorageBackendID': 3, 'ObjectKey': 'eyened/public_data/av_segmentation/HRF_AV/images/15_g.jpg', 'Hash': None, 'Checksum': None, 'Format': 'image/jpeg', 'IsPrimary': 1}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# ### Execution
#
# Once satisfied with the summary, commit the import to the database with `importer.exec`
# There might still be Exceptions generated during import, in which case nothing will change in the DB and no files will be written.
#
# Post-insertion scripts will run after insertion for non-essential steps such as:
#
# - Thumbnail generation (highly recommended to run)
# - Running image preprocessing scripts (eg. CFI bounds detection)
# - Running AI models which populate DB columns
# - Hashing the files for error and duplicate checks

# %%
importer.import_many(data)
# Out:
# [ImageInstance(ImageInstanceID=99, PublicID=0lz1gfcq, SeriesID=11, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=117, PublicID=c0ln0jvm, SeriesID=13, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=91, PublicID=h9mgy8re, SeriesID=11, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=98, PublicID=91jv132g, SeriesID=11, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=109, PublicID=f32zy74m, SeriesID=12, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=131, PublicID=sbn594pb, SeriesID=15, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=108, PublicID=bqbmoscx, SeriesID=12, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=103, PublicID=z2y453vz, SeriesID=12, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=126, PublicID=behjx4pt, SeriesID=14, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=128, PublicID=gtsxem33, SeriesID=14, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=105, PublicID=cv59dgwe, SeriesID=12, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=121, PublicID=hhkufbbv, SeriesID=14, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=107, PublicID=20y81gg8, SeriesID=12, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=125, PublicID=49s90hqz, SeriesID=14, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=114, PublicID=4487g9hb, SeriesID=13, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=133, PublicID=uy2307j4, SeriesID=15, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=115, PublicID=ha7kdvom, SeriesID=13, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=124, PublicID=p55vpmj0, SeriesID=14, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=123, PublicID=jp6k5ys6, SeriesID=14, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=97, PublicID=fqjlguvh, SeriesID=11, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=118, PublicID=s7xdy8wl, SeriesID=13, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=132, PublicID=dqv64zkp, SeriesID=15, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=113, PublicID=6ufbvzfj, SeriesID=13, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=127, PublicID=zzzas1nl, SeriesID=14, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=134, PublicID=d4a4pyoe, SeriesID=15, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=92, PublicID=fhlhdpni, SeriesID=11, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=119, PublicID=ytn2rv8i, SeriesID=13, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=130, PublicID=uxiyh06s, SeriesID=14, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=101, PublicID=b1fcv1db, SeriesID=12, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=106, PublicID=pbtgmmhn, SeriesID=12, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=110, PublicID=lbb7jmyf, SeriesID=12, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=93, PublicID=knku6w7q, SeriesID=11, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=102, PublicID=j9lbscqu, SeriesID=12, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=129, PublicID=t9xaj4dw, SeriesID=14, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=120, PublicID=dc2vgcn2, SeriesID=13, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=94, PublicID=swqthqba, SeriesID=11, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=100, PublicID=via2z7yq, SeriesID=11, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=104, PublicID=y1bn44bv, SeriesID=12, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=95, PublicID=3g22jjhi, SeriesID=11, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=112, PublicID=za02y0tn, SeriesID=13, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=135, PublicID=kmy6le2w, SeriesID=15, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=96, PublicID=8w23mg3y, SeriesID=11, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=111, PublicID=7ev59wxd, SeriesID=13, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=116, PublicID=txocoxey, SeriesID=13, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=122, PublicID=v34gr33e, SeriesID=14, SourceInfoID=None, DeviceInstanceID=3, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=, AltDatasetIdentifier=None, ThumbnailPath=None, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-11 11:50:03, DateModified=None, DatePreprocessed=None)]

# %% [markdown]
# ### Inspect Results
#
# The project is now in the DB. We can easily generate a dataframe with image details to inspect results

# %%
# inspect the project using the ORM
from eyened_orm import Project

project = Project.by_name(session, 'FAU Fundus Dataset')

# %%
project.make_dataframe()
# Out:
#     ImageInstanceID  PublicID  SeriesID SourceInfoID  DeviceInstanceID  \
# 0                91  h9mgy8re        11         None                 3
# 1                92  fhlhdpni        11         None                 3
# 2                93  knku6w7q        11         None                 3
# 3                94  swqthqba        11         None                 3
# 4                95  3g22jjhi        11         None                 3
# 5                96  8w23mg3y        11         None                 3
# 6                97  fqjlguvh        11         None                 3
# 7                98  91jv132g        11         None                 3
# 8                99  0lz1gfcq        11         None                 3
# 9               100  via2z7yq        11         None                 3
# 10              101  b1fcv1db        12         None                 3
# 11              102  j9lbscqu        12         None                 3
# 12              103  z2y453vz        12         None                 3
# 13              104  y1bn44bv        12         None                 3
# 14              105  cv59dgwe        12         None                 3
# 15              106  pbtgmmhn        12         None                 3
# 16              107  20y81gg8        12         None                 3
# 17              108  bqbmoscx        12         None                 3
# 18              109  f32zy74m        12         None                 3
# 19              110  lbb7jmyf        12         None                 3
# 20              111  7ev59wxd        13         None                 3
# 21              112  za02y0tn        13         None                 3
# 22              113  6ufbvzfj        13         None                 3
# 23              114  4487g9hb        13         None                 3
# 24              115  ha7kdvom        13         None                 3
# 25              116  txocoxey        13         None                 3
# 26              117  c0ln0jvm        13         None                 3
# 27              118  s7xdy8wl        13         None                 3
# 28              119  ytn2rv8i        13         None                 3
# 29              120  dc2vgcn2        13         None                 3
# 30              121  hhkufbbv        14         None                 3
# 31              122  v34gr33e        14         None                 3
# 32              123  jp6k5ys6        14         None                 3
# 33              124  p55vpmj0        14         None                 3
# 34              125  49s90hqz        14         None                 3
# 35              126  behjx4pt        14         None                 3
# 36              127  zzzas1nl        14         None                 3
# 37              128  gtsxem33        14         None                 3
# 38              129  t9xaj4dw        14         None                 3
# 39              130  uxiyh06s        14         None                 3
# 40              131  sbn594pb        15         None                 3
# 41              132  dqv64zkp        15         None                 3
# 42              133  uy2307j4        15         None                 3
# 43              134  d4a4pyoe        15         None                 3
# 44              135  kmy6le2w        15         None                 3
#
#    ModalityID ScanID Modality SOPInstanceUid SOPClassUid  ... ThumbnailPath  \
# 0        None   None     None           None        None  ...          None
# 1        None   None     None           None        None  ...          None
# 2        None   None     None           None        None  ...          None
# 3        None   None     None           None        None  ...          None
# 4        None   None     None           None        None  ...          None
# 5        None   None     None           None        None  ...          None
# 6        None   None     None           None        None  ...          None
# 7        None   None     None           None        None  ...          None
# 8        None   None     None           None        None  ...          None
# 9        None   None     None           None        None  ...          None
# 10       None   None     None           None        None  ...          None
# 11       None   None     None           None        None  ...          None
# 12       None   None     None           None        None  ...          None
# 13       None   None     None           None        None  ...          None
# 14       None   None     None           None        None  ...          None
# 15       None   None     None           None        None  ...          None
# 16       None   None     None           None        None  ...          None
# 17       None   None     None           None        None  ...          None
# 18       None   None     None           None        None  ...          None
# 19       None   None     None           None        None  ...          None
# 20       None   None     None           None        None  ...          None
# 21       None   None     None           None        None  ...          None
# 22       None   None     None           None        None  ...          None
# 23       None   None     None           None        None  ...          None
# 24       None   None     None           None        None  ...          None
# 25       None   None     None           None        None  ...          None
# 26       None   None     None           None        None  ...          None
# 27       None   None     None           None        None  ...          None
# 28       None   None     None           None        None  ...          None
# 29       None   None     None           None        None  ...          None
# 30       None   None     None           None        None  ...          None
# 31       None   None     None           None        None  ...          None
# 32       None   None     None           None        None  ...          None
# 33       None   None     None           None        None  ...          None
# 34       None   None     None           None        None  ...          None
# 35       None   None     None           None        None  ...          None
# 36       None   None     None           None        None  ...          None
# 37       None   None     None           None        None  ...          None
# 38       None   None     None           None        None  ...          None
# 39       None   None     None           None        None  ...          None
# 40       None   None     None           None        None  ...          None
# 41       None   None     None           None        None  ...          None
# 42       None   None     None           None        None  ...          None
# 43       None   None     None           None        None  ...          None
# 44       None   None     None           None        None  ...          None
#
#    OldPath FDAIdentifier Inactive CFROI CFKeypoints CFQuality  \
# 0     None          None    False  None        None      None
# 1     None          None    False  None        None      None
# 2     None          None    False  None        None      None
# 3     None          None    False  None        None      None
# 4     None          None    False  None        None      None
# 5     None          None    False  None        None      None
# 6     None          None    False  None        None      None
# 7     None          None    False  None        None      None
# 8     None          None    False  None        None      None
# 9     None          None    False  None        None      None
# 10    None          None    False  None        None      None
# 11    None          None    False  None        None      None
# 12    None          None    False  None        None      None
# 13    None          None    False  None        None      None
# 14    None          None    False  None        None      None
# 15    None          None    False  None        None      None
# 16    None          None    False  None        None      None
# 17    None          None    False  None        None      None
# 18    None          None    False  None        None      None
# 19    None          None    False  None        None      None
# 20    None          None    False  None        None      None
# 21    None          None    False  None        None      None
# 22    None          None    False  None        None      None
# 23    None          None    False  None        None      None
# 24    None          None    False  None        None      None
# 25    None          None    False  None        None      None
# 26    None          None    False  None        None      None
# 27    None          None    False  None        None      None
# 28    None          None    False  None        None      None
# 29    None          None    False  None        None      None
# 30    None          None    False  None        None      None
# 31    None          None    False  None        None      None
# 32    None          None    False  None        None      None
# 33    None          None    False  None        None      None
# 34    None          None    False  None        None      None
# 35    None          None    False  None        None      None
# 36    None          None    False  None        None      None
# 37    None          None    False  None        None      None
# 38    None          None    False  None        None      None
# 39    None          None    False  None        None      None
# 40    None          None    False  None        None      None
# 41    None          None    False  None        None      None
# 42    None          None    False  None        None      None
# 43    None          None    False  None        None      None
# 44    None          None    False  None        None      None
#
#           DateInserted DateModified DatePreprocessed
# 0  2026-03-11 11:50:03         None             None
# 1  2026-03-11 11:50:03         None             None
# 2  2026-03-11 11:50:03         None             None
# 3  2026-03-11 11:50:03         None             None
# 4  2026-03-11 11:50:03         None             None
# 5  2026-03-11 11:50:03         None             None
# 6  2026-03-11 11:50:03         None             None
# 7  2026-03-11 11:50:03         None             None
# 8  2026-03-11 11:50:03         None             None
# 9  2026-03-11 11:50:03         None             None
# 10 2026-03-11 11:50:03         None             None
# 11 2026-03-11 11:50:03         None             None
# 12 2026-03-11 11:50:03         None             None
# 13 2026-03-11 11:50:03         None             None
# 14 2026-03-11 11:50:03         None             None
# 15 2026-03-11 11:50:03         None             None
# 16 2026-03-11 11:50:03         None             None
# 17 2026-03-11 11:50:03         None             None
# 18 2026-03-11 11:50:03         None             None
# 19 2026-03-11 11:50:03         None             None
# 20 2026-03-11 11:50:03         None             None
# 21 2026-03-11 11:50:03         None             None
# 22 2026-03-11 11:50:03         None             None
# 23 2026-03-11 11:50:03         None             None
# 24 2026-03-11 11:50:03         None             None
# 25 2026-03-11 11:50:03         None             None
# 26 2026-03-11 11:50:03         None             None
# 27 2026-03-11 11:50:03         None             None
# 28 2026-03-11 11:50:03         None             None
# 29 2026-03-11 11:50:03         None             None
# 30 2026-03-11 11:50:03         None             None
# 31 2026-03-11 11:50:03         None             None
# 32 2026-03-11 11:50:03         None             None
# 33 2026-03-11 11:50:03         None             None
# 34 2026-03-11 11:50:03         None             None
# 35 2026-03-11 11:50:03         None             None
# 36 2026-03-11 11:50:03         None             None
# 37 2026-03-11 11:50:03         None             None
# 38 2026-03-11 11:50:03         None             None
# 39 2026-03-11 11:50:03         None             None
# 40 2026-03-11 11:50:03         None             None
# 41 2026-03-11 11:50:03         None             None
# 42 2026-03-11 11:50:03         None             None
# 43 2026-03-11 11:50:03         None             None
# 44 2026-03-11 11:50:03         None             None
#
# [45 rows x 39 columns]

# %%
raise Exception("Stop here")

# %% [markdown]
# ### Updating existing projects
#
# Images can be inserted into existing projects, patients, studies and series by passing an existing project name, patient_identifier, study_date or series_id in the input structure. These will be matched to database entities (taking into account their nested structure).

# %%
# to simulate inserting into an existing project, we'll insert the same data again
# use create_patients=False, create_studies=False, create_series=False when inserting into existing objects to ensure that no new objects will be created
# copy_files=True will copy the files to a configurable directory
importer = Importer(
    session=session,
    run_ai_models=True, 
    generate_thumbnails=True,
    # copy_files=True # removed copy_files as it wasn't in __init__ signature I read
)

# Display a summary of what will be imported
import_summary = importer.import_many(data, summary=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 12
#       4 importer = Importer(
#       5     session=session,
#       6     run_ai_models=True,
#       7     generate_thumbnails=True,
#       8     # copy_files=True # removed copy_files as it wasn't in __init__ signature I read
#       9 )
#      11 # Display a summary of what will be imported
# ---> 12 import_summary = importer.import_many(data, summary=True)
#
# File ~/eyened-platform/orm/eyened_orm/importer/importer.py:857, in Importer.import_many(self, data, summary)
#     855 try:
#     856     if summary:
# --> 857         return self._summary(data)
#     858     else:
#     859         return self._import(data)
#
# File ~/eyened-platform/orm/eyened_orm/importer/importer.py:735, in Importer._summary(self, data)
#     733 def _summary(self, data: List[PatientImport]) -> Dict:
#     734     with self.session.begin_nested():
# --> 735         self.init_objects(data)
#     737         class_map = {
#     738             "patients": Patient,
#     739             "studies": Study,
#    (...)
#     747             "scans": Scan,
#     748         }
#     749         entities = {}
#
# File ~/eyened-platform/orm/eyened_orm/importer/importer.py:132, in Importer.init_objects(self, data)
#     129 # Process each patient
#     130 for patient_item in data:
#     131     # Get or create the project for this patient
# --> 132     project = self.get_or_create_project(patient_item.project_name)
#     134     patient = self.find_or_create_patient(patient_item, project)
#     135     self.patients.append(patient)
#
# File ~/eyened-platform/orm/eyened_orm/importer/importer.py:273, in Importer.get_or_create_project(self, project_name)
#     271 if project is None:
#     272     if not self.create_projects:
# --> 273         raise RuntimeError(
#     274             f"Project with name '{project_name}' not found and create_projects=False"
#     275         )
#     276     project = Project(ProjectName=project_name, External=ExternalEnum.Y)
#     277     self.session.add(project)
#
# RuntimeError: Project with name 'FAU Fundus Dataset' not found and create_projects=False

# %%
importer.import_many(data)
# Out:
# 100%|██████████| 45/45 [00:00<00:00, 57264.47it/s]
# No images to process
# [ImageInstance(ImageInstanceID=136, PublicID=a6c6dl5q, SeriesID=106, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/15_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=137, PublicID=xra9wozv, SeriesID=106, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/05_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=138, PublicID=ggapy570, SeriesID=106, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/15_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=139, PublicID=1me2rlvj, SeriesID=106, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/06_dr.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=140, PublicID=k2hmrvlb, SeriesID=106, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/01_dr.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=141, PublicID=752vqo7p, SeriesID=106, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/10_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=142, PublicID=7x546ywq, SeriesID=106, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/12_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=143, PublicID=lf8o3gs8, SeriesID=106, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/14_dr.JPG, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=144, PublicID=2x7ckhdb, SeriesID=106, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/15_dr.JPG, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=145, PublicID=j4fyedpq, SeriesID=106, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/13_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=146, PublicID=r9doujwa, SeriesID=107, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/06_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=147, PublicID=zvfemdyx, SeriesID=107, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/04_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=148, PublicID=gmi35q9g, SeriesID=107, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/14_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=149, PublicID=6pr1l849, SeriesID=107, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/09_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=150, PublicID=bnz05e3r, SeriesID=107, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/02_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=151, PublicID=fja793j3, SeriesID=107, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/08_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=152, PublicID=roe4fwez, SeriesID=107, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/03_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=153, PublicID=l7lpelz6, SeriesID=107, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/05_dr.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=154, PublicID=feqf7xpq, SeriesID=107, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/10_dr.JPG, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=155, PublicID=z1amiy74, SeriesID=107, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/11_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=156, PublicID=u5pok654, SeriesID=108, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/03_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=157, PublicID=g80b8mtw, SeriesID=108, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/10_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=158, PublicID=ihmhv73a, SeriesID=108, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/01_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=159, PublicID=itxx5hca, SeriesID=108, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/09_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=160, PublicID=qvdl36rb, SeriesID=108, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/07_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=161, PublicID=g3kjant8, SeriesID=108, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/12_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=162, PublicID=i4hnol5r, SeriesID=108, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/13_dr.JPG, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=163, PublicID=b0oopzr9, SeriesID=108, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/03_dr.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=164, PublicID=zt66wakh, SeriesID=108, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/Thumbs.db, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=165, PublicID=uqm7gmja, SeriesID=108, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/11_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=166, PublicID=4yq91vtv, SeriesID=109, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/07_dr.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=167, PublicID=w836bq14, SeriesID=109, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/08_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=168, PublicID=td0whmgo, SeriesID=109, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/05_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=169, PublicID=e33diwt5, SeriesID=109, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/14_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=170, PublicID=nxp9iynz, SeriesID=109, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/04_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=171, PublicID=tiooke6a, SeriesID=109, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/12_dr.JPG, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=172, PublicID=2jckg961, SeriesID=109, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/02_dr.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=173, PublicID=vynz0t1l, SeriesID=109, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/11_dr.JPG, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=174, PublicID=aqbt03nj, SeriesID=109, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/13_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=175, PublicID=m3brf62g, SeriesID=109, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/02_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=176, PublicID=6fq7nldz, SeriesID=110, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/08_dr.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=177, PublicID=lza6yjo8, SeriesID=110, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/01_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=178, PublicID=vfn8fzmz, SeriesID=110, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/06_h.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=179, PublicID=z188pzxm, SeriesID=110, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/07_g.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None),
#  ImageInstance(ImageInstanceID=180, PublicID=vj4xir1u, SeriesID=110, SourceInfoID=None, DeviceInstanceID=1, ModalityID=None, ScanID=None, Modality=None, SOPInstanceUid=None, SOPClassUid=None, PhotometricInterpretation=None, SamplesPerPixel=None, Rows_y=None, Columns_x=None, NrOfFrames=None, SliceThickness=None, ResolutionAxial=None, ResolutionHorizontal=None, ResolutionVertical=None, HorizontalFieldOfView=None, Laterality=None, DICOMModality=None, AnatomicRegion=None, ETDRSField=None, Angiography=None, AcquisitionDateTime=None, PupilDilated=None, DatasetIdentifier=eyened/public_data/av_segmentation/HRF_AV/images/04_dr.jpg, AltDatasetIdentifier=None, ThumbnailPath=, OldPath=None, FDAIdentifier=None, Inactive=False, CFROI=None, CFKeypoints=None, CFQuality=None, DateInserted=2026-03-10 16:48:14, DateModified=2026-03-10 16:48:14, DatePreprocessed=None)]

# %%
project = Project.by_name(session, 'FAU Fundus Dataset')
project.make_dataframe()
# Out:
#     ImageInstanceID  PublicID  SeriesID SourceInfoID  DeviceInstanceID  \
# 0                91  texke9in        96         None                 1
# 1                92  oepw2871        96         None                 1
# 2                93  a4ngali0        96         None                 1
# 3                94  w5nm1ell        96         None                 1
# 4                95  41aqx44d        96         None                 1
# ..              ...       ...       ...          ...               ...
# 85              176  6fq7nldz       110         None                 1
# 86              177  lza6yjo8       110         None                 1
# 87              178  vfn8fzmz       110         None                 1
# 88              179  z188pzxm       110         None                 1
# 89              180  vj4xir1u       110         None                 1
#
#    ModalityID ScanID Modality SOPInstanceUid SOPClassUid  ... ThumbnailPath  \
# 0        None   None     None           None        None  ...
# 1        None   None     None           None        None  ...
# 2        None   None     None           None        None  ...
# 3        None   None     None           None        None  ...
# 4        None   None     None           None        None  ...
# ..        ...    ...      ...            ...         ...  ...           ...
# 85       None   None     None           None        None  ...
# 86       None   None     None           None        None  ...
# 87       None   None     None           None        None  ...
# 88       None   None     None           None        None  ...
# 89       None   None     None           None        None  ...
#
#    OldPath FDAIdentifier Inactive CFROI CFKeypoints CFQuality  \
# 0     None          None    False  None        None      None
# 1     None          None    False  None        None      None
# 2     None          None    False  None        None      None
# 3     None          None    False  None        None      None
# 4     None          None    False  None        None      None
# ..     ...           ...      ...   ...         ...       ...
# 85    None          None    False  None        None      None
# 86    None          None    False  None        None      None
# 87    None          None    False  None        None      None
# 88    None          None    False  None        None      None
# 89    None          None    False  None        None      None
#
#           DateInserted        DateModified DatePreprocessed
# 0  2026-03-10 16:47:22 2026-03-10 16:47:22             None
# 1  2026-03-10 16:47:22 2026-03-10 16:47:22             None
# 2  2026-03-10 16:47:22 2026-03-10 16:47:22             None
# 3  2026-03-10 16:47:22 2026-03-10 16:47:22             None
# 4  2026-03-10 16:47:22 2026-03-10 16:47:22             None
# ..                 ...                 ...              ...
# 85 2026-03-10 16:48:14 2026-03-10 16:48:14             None
# 86 2026-03-10 16:48:14 2026-03-10 16:48:14             None
# 87 2026-03-10 16:48:14 2026-03-10 16:48:14             None
# 88 2026-03-10 16:48:14 2026-03-10 16:48:14             None
# 89 2026-03-10 16:48:14 2026-03-10 16:48:14             None
#
# [90 rows x 39 columns]
