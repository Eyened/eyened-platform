# %%
from pathlib import Path
from tqdm.notebook import tqdm

# Import the Importer class
from eyened_orm.importer.importer import Importer
from eyened_orm import DBManager
from eyened_orm.utils.config import get_config

# from rtnls_fundusprep.preprocessor import FundusPreprocessor
# from rtnls_fundusprep.utils import preprocess_for_inference
from tqdm.notebook import tqdm

# %%
config = get_config("test")
DBManager.init(config)
session = DBManager.get_session()

# %%
# Set up project information
project_name = "FAU Fundus Dataset"

# %%
extract_dir = Path("/mnt/oogergo/eyened/public_data/av_segmentation/HRF_AV")

# %%
# Get all image paths
images_dir = extract_dir / "images"
image_paths = list(images_dir.glob("*"))

print(f"Found {len(image_paths)} images.")
# Out:
# Found 45 images.

# %%
# The dataset has images named as g0001.jpg, g0002.jpg, etc.
# Let's group images together in batches to demonstrate the hierarchy

# Create the data structure for the Importer
# Even though in this dataset each image is of a different patient
# We'll create one "patient" for every 10 images as an example
from datetime import date


data = []
batch_size = 10

for i in range(0, len(image_paths), batch_size):
    batch_images = image_paths[i : i + batch_size]

    # Create a patient entry (without identifier, will be auto-generated)
    patient_item = {
        "patient_identifier": f"Patient_{i // batch_size + 1}",
        "studies": [
            {
                "study_date": date.today(),
                "series": [
                    {
                        "images": [
                            {
                                "image": str(img_path.absolute()),
                                "props": {"OldPath": img_path.stem},
                            }
                            for img_path in batch_images
                        ],
                    }
                ],
            }
        ],
    }

    data.append(patient_item)

print(f"Created data structure with {len(data)} patients.")
print(f"First patient has {len(data[0]['studies'][0]['series'][0]['images'])} images.")
# Out:
# Created data structure with 5 patients.
# First patient has 10 images.

# %% [markdown]
# ### Summaries
#
# The summary method will return a summary of created ORM objects without writing anything to the database

# %%
# Create the importer with default settings
# Because none of the objects exist
# We run into an error if we run with default settings: create_series=True, create_studies=False, create_patients=False
importer = Importer(
    session=session,
    project_name=project_name,
    run_ai_models=True, 
    generate_thumbnails=True,
)

# Display a summary of what will be imported
import_summary = importer.summary(data)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 12
#       4 importer = Importer(
#       5     session=session,
#       6     project_name=project_name,
#       7     run_ai_models=True,
#       8     generate_thumbnails=True,
#       9 )
#      11 # Display a summary of what will be imported
# ---> 12 import_summary = importer.summary(data)
#
# File ~/viewer/eyened_orm/eyened_orm/importer/importer.py:482, in Importer.summary(self, data)
#     479 # Begin a nested transaction that we can roll back at the end
#     480 with self.session.begin_nested():
#     481     # Create the hierarchy of objects
# --> 482     self.create_patient_study_series(data)
#     484     # Create image instances to analyze columns
#     485     image_instances = self.create_image_instances(data)
#
# File ~/viewer/eyened_orm/eyened_orm/importer/importer.py:138, in Importer.create_patient_study_series(self, data)
#     136 if patient is None:
#     137     if not self.create_patients:
# --> 138         raise RuntimeError(
#     139             f"Patient with identifier '{patient_identifier}' not found and create_patients=False"
#     140         )
#     142     # Create new patient
#     143     patient = Patient(**patient_props)
#
# RuntimeError: Patient with identifier 'Patient_1' not found and create_patients=False

# %%
# We need to specify create_patients=True, create_studies=True
# since we're not providing identifiers
importer = Importer(
    session=session,
    project_name=project_name,
    create_patients=True,
    create_studies=True,
    run_ai_models=False, 
    generate_thumbnails=True,
)

# Display a summary of what will be imported
import_summary = importer.summary(data)
# Out:
# Import Summary for Project: FAU Fundus Dataset
# ----------------  Object Statistics  ----------------
#   Entity  Total  New  Existing
# Patients      5    5         0
#  Studies      5    5         0
#   Series      5    5         0
#   Images     45   45         0
# -----------  Column Population Statistics  -----------
# - only for new entities
# - values set to NULL are not considered populated
#
# Populated Patient Columns:
#            Column  Populated Percentage
# PatientIdentifier          5     100.0%
#
# Populated Study Columns:
#    Column  Populated Percentage
# StudyDate          5     100.0%
#
# Populated Series Columns:
# No populated columns found
#
# Populated Image Columns:
#            Column  Populated Percentage
# DatasetIdentifier         45     100.0%
#           OldPath         45     100.0%

# %% [markdown]
# ### Execution
#
# Once satisfied with the summary, commit the import to the database with `importer.exec`
# There might still be Exceptions generated during import, in which case nothing will change in the DB and no files will be written.
#
# Post-insertion scripts will run after insertion for non-essential steps such as:
#
# - Thumbnail generation (highly recommended to run)
# - Running image preprocessing scripts (eg. CFI bounds detection)
# - Running AI models which populate DB columns
# - Hashing the files for error and duplicate checks

# %%
importer.exec(data)
# Out:
# Created 45 image instances
# Successfully committed to database
# Running post-processing:  75%|███████▌  | 3/4 [00:00<00:00,  4.11it/s]
# Found 46 images without thumbnails
#   0%|          | 0/46 [00:00<?, ?it/s]
#   2%|▏         | 1/46 [00:00<00:13,  3.37it/s]
#   4%|▍         | 2/46 [00:00<00:11,  3.93it/s]
#   7%|▋         | 3/46 [00:00<00:10,  4.23it/s]
#   9%|▊         | 4/46 [00:00<00:09,  4.39it/s]
#  11%|█         | 5/46 [00:01<00:09,  4.55it/s]
#  13%|█▎        | 6/46 [00:01<00:09,  4.02it/s]
#  15%|█▌        | 7/46 [00:01<00:11,  3.29it/s]
#  17%|█▋        | 8/46 [00:02<00:11,  3.31it/s]
#  20%|█▉        | 9/46 [00:02<00:09,  3.87it/s]
#  22%|██▏       | 10/46 [00:02<00:08,  4.27it/s]
#  26%|██▌       | 12/46 [00:03<00:11,  3.00it/s]
#  28%|██▊       | 13/46 [00:03<00:10,  3.23it/s]
#  30%|███       | 14/46 [00:03<00:09,  3.49it/s]
#  33%|███▎      | 15/46 [00:04<00:08,  3.51it/s]
#  35%|███▍      | 16/46 [00:04<00:07,  3.82it/s]
#  37%|███▋      | 17/46 [00:04<00:07,  4.12it/s]
#  39%|███▉      | 18/46 [00:04<00:06,  4.20it/s]
#  41%|████▏     | 19/46 [00:05<00:07,  3.80it/s]
#  43%|████▎     | 20/46 [00:05<00:07,  3.55it/s]
#  46%|████▌     | 21/46 [00:05<00:06,  3.65it/s]
#  48%|████▊     | 22/46 [00:05<00:05,  4.14it/s]
#  50%|█████     | 23/46 [00:06<00:05,  4.04it/s]
#  52%|█████▏    | 24/46 [00:06<00:05,  4.06it/s]
#  54%|█████▍    | 25/46 [00:06<00:06,  3.22it/s]
#  57%|█████▋    | 26/46 [00:07<00:06,  3.12it/s]
#  59%|█████▊    | 27/46 [00:07<00:05,  3.42it/s]
#  61%|██████    | 28/46 [00:07<00:04,  3.65it/s]
#  63%|██████▎   | 29/46 [00:07<00:04,  3.84it/s]
#  65%|██████▌   | 30/46 [00:08<00:03,  4.10it/s]
#  67%|██████▋   | 31/46 [00:08<00:04,  3.46it/s]
#  70%|██████▉   | 32/46 [00:08<00:03,  3.53it/s]
#  72%|███████▏  | 33/46 [00:08<00:03,  3.53it/s]
#  74%|███████▍  | 34/46 [00:09<00:03,  3.90it/s]
#  76%|███████▌  | 35/46 [00:09<00:02,  4.23it/s]
#  78%|███████▊  | 36/46 [00:09<00:02,  3.74it/s]
#  80%|████████  | 37/46 [00:10<00:02,  3.30it/s]
#  83%|████████▎ | 38/46 [00:10<00:02,  3.59it/s]
#  85%|████████▍ | 39/46 [00:10<00:01,  3.76it/s]
#  87%|████████▋ | 40/46 [00:10<00:01,  4.04it/s]
#  89%|████████▉ | 41/46 [00:10<00:01,  4.46it/s]
#  91%|█████████▏| 42/46 [00:11<00:00,  4.68it/s]
#  93%|█████████▎| 43/46 [00:11<00:00,  4.59it/s]
#  96%|█████████▌| 44/46 [00:11<00:00,  4.47it/s]
#  98%|█████████▊| 45/46 [00:11<00:00,  4.84it/s]
# 100%|██████████| 46/46 [00:11<00:00,  3.85it/s]
# Running post-processing: 100%|██████████| 4/4 [00:12<00:00,  3.15s/it]
# Project(12035, FAU Fundus Dataset, 1)

# %% [markdown]
# ### Inspect Results
#
# The project is now in the DB. We can easily generate a dataframe with image details to inspect results

# %%
# inspect the project using the ORM
from eyened_orm import Project


project = Project.by_name(session, 'FAU Fundus Dataset')

# %%
project.make_dataframe(session)
# Out:
#     image_id  patient_id patient_identifier  study_id  study_date  series_id  \
# 0    2515790     1696747          Patient_1   1733668  2025-04-10    2003539
# 1    2515791     1696747          Patient_1   1733668  2025-04-10    2003539
# 2    2515792     1696747          Patient_1   1733668  2025-04-10    2003539
# 3    2515793     1696747          Patient_1   1733668  2025-04-10    2003539
# 4    2515794     1696747          Patient_1   1733668  2025-04-10    2003539
# 5    2515795     1696747          Patient_1   1733668  2025-04-10    2003539
# 6    2515796     1696747          Patient_1   1733668  2025-04-10    2003539
# 7    2515797     1696747          Patient_1   1733668  2025-04-10    2003539
# 8    2515798     1696747          Patient_1   1733668  2025-04-10    2003539
# 9    2515799     1696747          Patient_1   1733668  2025-04-10    2003539
# 10   2515800     1696748          Patient_2   1733669  2025-04-10    2003540
# 11   2515801     1696748          Patient_2   1733669  2025-04-10    2003540
# 12   2515802     1696748          Patient_2   1733669  2025-04-10    2003540
# 13   2515803     1696748          Patient_2   1733669  2025-04-10    2003540
# 14   2515804     1696748          Patient_2   1733669  2025-04-10    2003540
# 15   2515805     1696748          Patient_2   1733669  2025-04-10    2003540
# 16   2515806     1696748          Patient_2   1733669  2025-04-10    2003540
# 17   2515807     1696748          Patient_2   1733669  2025-04-10    2003540
# 18   2515808     1696748          Patient_2   1733669  2025-04-10    2003540
# 19   2515809     1696748          Patient_2   1733669  2025-04-10    2003540
# 20   2515810     1696749          Patient_3   1733670  2025-04-10    2003541
# 21   2515811     1696749          Patient_3   1733670  2025-04-10    2003541
# 22   2515812     1696749          Patient_3   1733670  2025-04-10    2003541
# 23   2515813     1696749          Patient_3   1733670  2025-04-10    2003541
# 24   2515814     1696749          Patient_3   1733670  2025-04-10    2003541
# 25   2515815     1696749          Patient_3   1733670  2025-04-10    2003541
# 26   2515816     1696749          Patient_3   1733670  2025-04-10    2003541
# 27   2515817     1696749          Patient_3   1733670  2025-04-10    2003541
# 28   2515818     1696749          Patient_3   1733670  2025-04-10    2003541
# 29   2515819     1696749          Patient_3   1733670  2025-04-10    2003541
# 30   2515820     1696750          Patient_4   1733671  2025-04-10    2003542
# 31   2515821     1696750          Patient_4   1733671  2025-04-10    2003542
# 32   2515822     1696750          Patient_4   1733671  2025-04-10    2003542
# 33   2515823     1696750          Patient_4   1733671  2025-04-10    2003542
# 34   2515824     1696750          Patient_4   1733671  2025-04-10    2003542
# 35   2515825     1696750          Patient_4   1733671  2025-04-10    2003542
# 36   2515826     1696750          Patient_4   1733671  2025-04-10    2003542
# 37   2515827     1696750          Patient_4   1733671  2025-04-10    2003542
# 38   2515828     1696750          Patient_4   1733671  2025-04-10    2003542
# 39   2515829     1696750          Patient_4   1733671  2025-04-10    2003542
# 40   2515830     1696751          Patient_5   1733672  2025-04-10    2003543
# 41   2515831     1696751          Patient_5   1733672  2025-04-10    2003543
# 42   2515832     1696751          Patient_5   1733672  2025-04-10    2003543
# 43   2515833     1696751          Patient_5   1733672  2025-04-10    2003543
# 44   2515834     1696751          Patient_5   1733672  2025-04-10    2003543
#
#                                                  path
# 0   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 1   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 2   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 3   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 4   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 5   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 6   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 7   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 8   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 9   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 10  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 11  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 12  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 13  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 14  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 15  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 16  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 17  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 18  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 19  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 20  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 21  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 22  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 23  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 24  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 25  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 26  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 27  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 28  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 29  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 30  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 31  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 32  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 33  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 34  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 35  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 36  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 37  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 38  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 39  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 40  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 41  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 42  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 43  /mnt/oogergo/eyened/public_data/av_segmentatio...
# 44  /mnt/oogergo/eyened/public_data/av_segmentatio...

# %% [markdown]
# ### Updating existing projects
#
# Images can be inserted into existing projects, patients, studies and series by passing an existing project name, patient_identifier, study_date or series_id in the input structure. These will be matched to database entities (taking into account their nested structure).

# %%
# to simulate inserting into an existing project, we'll insert the same data again
# use create_patients=False, create_studies=False, create_series=False when inserting into existing objects to ensure that no new objects will be created
# copy_files=True will copy the files to a configurable directory
importer = Importer(
    session=session,
    project_name=project_name,
    run_ai_models=True, 
    generate_thumbnails=True,
    copy_files=True
)

# Display a summary of what will be imported
import_summary = importer.summary(data)
# Out:
# Import Summary for Project: FAU Fundus Dataset
# ----------------  Object Statistics  ----------------
#   Entity  Total  New  Existing
# Patients      5    0         5
#  Studies      5    0         5
#   Series      5    5         0
#   Images     45   45         0
# -----------  Column Population Statistics  -----------
# - only for new entities
# - values set to NULL are not considered populated
#
# Populated Series Columns:
# No populated columns found
#
# Populated Image Columns:
#            Column  Populated Percentage
# DatasetIdentifier         45     100.0%
#           OldPath         45     100.0%

# %%
importer.exec(data)
# Out:
# Created 45 image instances
# Successfully committed to database
# Running post-processing:  80%|████████  | 4/5 [00:05<00:02,  2.40s/it]
# No images to process
# Found 45 images without thumbnails
#   0%|          | 0/45 [00:00<?, ?it/s]
#   2%|▏         | 1/45 [00:00<00:08,  4.90it/s]
#   4%|▍         | 2/45 [00:00<00:09,  4.61it/s]
#   7%|▋         | 3/45 [00:00<00:09,  4.60it/s]
#   9%|▉         | 4/45 [00:00<00:08,  4.81it/s]
#  11%|█         | 5/45 [00:01<00:08,  4.66it/s]
#  13%|█▎        | 6/45 [00:01<00:08,  4.51it/s]
#  16%|█▌        | 7/45 [00:01<00:07,  4.90it/s]
#  18%|█▊        | 8/45 [00:01<00:07,  4.81it/s]
#  20%|██        | 9/45 [00:01<00:08,  4.50it/s]
#  22%|██▏       | 10/45 [00:02<00:08,  4.07it/s]
#  24%|██▍       | 11/45 [00:02<00:08,  3.84it/s]
#  27%|██▋       | 12/45 [00:02<00:07,  4.21it/s]
#  29%|██▉       | 13/45 [00:03<00:08,  3.95it/s]
#  31%|███       | 14/45 [00:03<00:07,  4.40it/s]
#  33%|███▎      | 15/45 [00:03<00:07,  3.95it/s]
#  38%|███▊      | 17/45 [00:03<00:06,  4.55it/s]
#  40%|████      | 18/45 [00:04<00:06,  4.37it/s]
#  42%|████▏     | 19/45 [00:04<00:05,  4.35it/s]
#  44%|████▍     | 20/45 [00:04<00:07,  3.43it/s]
#  47%|████▋     | 21/45 [00:05<00:07,  3.39it/s]
#  49%|████▉     | 22/45 [00:05<00:06,  3.69it/s]
#  51%|█████     | 23/45 [00:05<00:05,  3.87it/s]
#  53%|█████▎    | 24/45 [00:05<00:05,  4.10it/s]
#  56%|█████▌    | 25/45 [00:06<00:05,  3.98it/s]
#  58%|█████▊    | 26/45 [00:06<00:05,  3.58it/s]
#  60%|██████    | 27/45 [00:06<00:04,  3.67it/s]
#  62%|██████▏   | 28/45 [00:06<00:04,  3.60it/s]
#  64%|██████▍   | 29/45 [00:07<00:04,  3.51it/s]
#  67%|██████▋   | 30/45 [00:07<00:03,  3.82it/s]
#  69%|██████▉   | 31/45 [00:07<00:03,  3.85it/s]
#  71%|███████   | 32/45 [00:07<00:03,  3.88it/s]
#  73%|███████▎  | 33/45 [00:08<00:03,  3.33it/s]
#  76%|███████▌  | 34/45 [00:08<00:02,  3.72it/s]
#  78%|███████▊  | 35/45 [00:08<00:02,  4.01it/s]
#  80%|████████  | 36/45 [00:08<00:02,  4.26it/s]
#  82%|████████▏ | 37/45 [00:09<00:01,  4.22it/s]
#  84%|████████▍ | 38/45 [00:09<00:02,  3.37it/s]
#  87%|████████▋ | 39/45 [00:09<00:01,  3.54it/s]
#  89%|████████▉ | 40/45 [00:10<00:01,  3.90it/s]
#  91%|█████████ | 41/45 [00:10<00:01,  3.68it/s]
#  93%|█████████▎| 42/45 [00:10<00:00,  3.85it/s]
#  96%|█████████▌| 43/45 [00:10<00:00,  4.26it/s]
#  98%|█████████▊| 44/45 [00:11<00:00,  3.11it/s]
# 100%|██████████| 45/45 [00:11<00:00,  3.83it/s]
# Running post-processing: 100%|██████████| 5/5 [00:20<00:00,  4.19s/it]
# Project(12035, FAU Fundus Dataset, 1)

# %%
project = Project.by_name(session, 'FAU Fundus Dataset')
project.make_dataframe(session)
# Out:
#     image_id  patient_id patient_identifier  study_id  study_date  series_id  \
# 0    2515790     1696747          Patient_1   1733668  2025-04-10    2003539
# 1    2515791     1696747          Patient_1   1733668  2025-04-10    2003539
# 2    2515792     1696747          Patient_1   1733668  2025-04-10    2003539
# 3    2515793     1696747          Patient_1   1733668  2025-04-10    2003539
# 4    2515794     1696747          Patient_1   1733668  2025-04-10    2003539
# ..       ...         ...                ...       ...         ...        ...
# 85   2515875     1696751          Patient_5   1733672  2025-04-10    2003548
# 86   2515876     1696751          Patient_5   1733672  2025-04-10    2003548
# 87   2515877     1696751          Patient_5   1733672  2025-04-10    2003548
# 88   2515878     1696751          Patient_5   1733672  2025-04-10    2003548
# 89   2515879     1696751          Patient_5   1733672  2025-04-10    2003548
#
#                                                  path
# 0   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 1   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 2   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 3   /mnt/oogergo/eyened/public_data/av_segmentatio...
# 4   /mnt/oogergo/eyened/public_data/av_segmentatio...
# ..                                                ...
# 85  /mnt/oogergo/eyened/misc/197411f47c743cedebd4d...
# 86  /mnt/oogergo/eyened/misc/ff079a12ea468e4a1843b...
# 87  /mnt/oogergo/eyened/misc/7004f016d2a0e3ea27891...
# 88  /mnt/oogergo/eyened/misc/7c64c16a7de76f9e3187a...
# 89  /mnt/oogergo/eyened/misc/f63497b4052f90ad004f6...
#
# [90 rows x 7 columns]
