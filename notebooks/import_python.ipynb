# %%
from pathlib import Path
from tqdm.notebook import tqdm

# Import the Importer class
from eyened_orm.importer.importer import Importer
from eyened_orm.importer.importer_dtos import PatientImport, StudyImport, SeriesImport, ImageImport
from eyened_orm import Database
from eyened_orm.utils.config import load_config

# from rtnls_fundusprep.preprocessor import FundusPreprocessor
# from rtnls_fundusprep.utils import preprocess_for_inference
from tqdm.notebook import tqdm

# %%
config = load_config('/home/jose/vessels/eyened_platform/dev/.env')
session = Database(config).create_session()

# %%
# Set up project information
project_name = "FAU Fundus Dataset"

# %%
extract_dir = Path("/mnt/oogergo/eyened/public_data/av_segmentation/HRF_AV")

# %%
# Get all image paths
images_dir = extract_dir / "images"
image_paths = list(images_dir.glob("*"))

print(f"Found {len(image_paths)} images.")
# Out:
# Found 45 images.

# %%
# The dataset has images named as g0001.jpg, g0002.jpg, etc.
# Let's group images together in batches to demonstrate the hierarchy

# Create the data structure for the Importer
# Even though in this dataset each image is of a different patient
# We'll create one "patient" for every 10 images as an example
from datetime import date


data = []
batch_size = 10

for i in range(0, len(image_paths), batch_size):
    batch_images = image_paths[i : i + batch_size]

    # Create image objects
    images = []
    for img_path in batch_images:
        images.append(ImageImport(
            image=str(img_path.absolute()),
            old_path=img_path.stem
        ))
    
    # Create hierarchy objects
    series = SeriesImport(images=images)
    study = StudyImport(study_date=date.today(), series=[series])
    
    patient_item = PatientImport(
        project_name=project_name,
        patient_identifier=f"Patient_{i // batch_size + 1}",
        studies=[study]
    )

    data.append(patient_item)

print(f"Created data structure with {len(data)} patients.")
print(f"First patient has {len(data[0].studies[0].series[0].images)} images.")
# Out:
# Created data structure with 5 patients.
# First patient has 10 images.

# %% [markdown]
# ### Summaries
#
# The summary method will return a summary of created ORM objects without writing anything to the database

# %%
# We need to specify create_patients=True, create_studies=True
# since we're not providing identifiers
importer = Importer(
    session=session,
    config=config,
    create_projects=True,
    create_patients=True,
    create_studies=True,
    run_ai_models=False, 
    generate_thumbnails=True,
)

# Display a summary of what will be imported
import_summary = importer.import_many(data, summary=True)
# Out:
# Import Summary for Projects: FAU Fundus Dataset, FAU Fundus Dataset, FAU Fundus Dataset, FAU Fundus Dataset, FAU Fundus Dataset
# ----------------  Object Statistics  ----------------
#                Entity  Total  New  Existing New_Percentage Existing_Percentage
#              Patients      5    5         0         100.0%                0.0%
#               Studies      5    5         0         100.0%                0.0%
#                Series      5    5         0         100.0%                0.0%
#                Images     45   45         0         100.0%                0.0%
# Attribute_definitions      0    0         0           0.0%                0.0%
#      Attribute_values      0    0         0           0.0%                0.0%
#         Segmentations      0    0         0           0.0%                0.0%
#
# -----------  Column Population Statistics  -----------
# - only for new entities
# - values set to NULL are not considered populated
#
# Populated Patients Columns:
#            Column  Populated Percentage
# PatientIdentifier          5     100.0%
#
# Populated Studies Columns:
#    Column  Populated Percentage
# StudyDate          5     100.0%
#
# Populated Images Columns:
#            Column  Populated Percentage
# DatasetIdentifier         45     100.0%
#           OldPath         45     100.0%
# /home/jose/vessels/eyened_platform/orm/eyened_orm/importer/importer.py:496: SAWarning: Object of type <ImageInstance> not in session, add operation along 'SourceInfo.ImageInstances' will not proceed
#   with self.session.begin_nested():

# %%
# # Create the importer with default settings
# # Because none of the objects exist
# # We run into an error if we run with default settings: create_series=True, create_studies=False, create_patients=False
# importer = Importer(
#     session=session,
#     # project_name=project_name, # Removed as it is now passed in PatientImport
#     config=config,
#     run_ai_models=True, 
#     generate_thumbnails=True,
# )

# # Display a summary of what will be imported
# import_summary = importer.import_many(data, summary=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 13
#       4 importer = Importer(
#       5     session=session,
#       6     # project_name=project_name, # Removed as it is now passed in PatientImport
#    (...)
#       9     generate_thumbnails=True,
#      10 )
#      12 # Display a summary of what will be imported
# ---> 13 import_summary = importer.import_many(data, summary=True)
#
# File ~/vessels/eyened_platform/orm/eyened_orm/importer/importer.py:639, in Importer.import_many(self, data, summary)
#     637 try:
#     638     if summary:
# --> 639         return self._summary(data)
#     640     else:
#     641         return self._import(data)
#
# File ~/vessels/eyened_platform/orm/eyened_orm/importer/importer.py:495, in Importer._summary(self, data)
#     493 def _summary(self, data: List[PatientImport]) -> Dict:
#     494     with self.session.begin_nested():
# --> 495         self.init_objects(data)
#     497         class_map = {
#     498             "patients": Patient,
#     499             "studies": Study,
#    (...)
#     504             "segmentations": Segmentation,
#     505         }
#     506         entities = {}
#
# File ~/vessels/eyened_platform/orm/eyened_orm/importer/importer.py:126, in Importer.init_objects(self, data)
#     123 # Process each patient
#     124 for patient_item in data:
#     125     # Find or create the project for this patient
# --> 126     project = self.find_or_create_projects(patient_item.project_name)
#     127     self.projects.append(project)
#     129     patient = self.find_or_create_patient(patient_item, project)
#
# File ~/vessels/eyened_platform/orm/eyened_orm/importer/importer.py:249, in Importer.find_or_create_projects(self, project_name)
#     247 if project is None:
#     248     if not self.create_projects:
# --> 249         raise RuntimeError(
#     250             f"Project with name '{project_name}' not found and create_projects=False"
#     251         )
#     252     project = Project(ProjectName=project_name, External=ExternalEnum.Y)
#     254 return project
#
# RuntimeError: Project with name 'FAU Fundus Dataset' not found and create_projects=False

# %% [markdown]
# ### Execution
#
# Once satisfied with the summary, commit the import to the database with `importer.exec`
# There might still be Exceptions generated during import, in which case nothing will change in the DB and no files will be written.
#
# Post-insertion scripts will run after insertion for non-essential steps such as:
#
# - Thumbnail generation (highly recommended to run)
# - Running image preprocessing scripts (eg. CFI bounds detection)
# - Running AI models which populate DB columns
# - Hashing the files for error and duplicate checks

# %%
importer.import_many(data)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/cursors.py:148, in Cursor.execute(self, query, args)
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/cursors.py:310, in Cursor._query(self, q)
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/connections.py:548, in Connection.query(self, sql, unbuffered)
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/connections.py:775, in Connection._read_query_result(self, unbuffered)
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/connections.py:1156, in MySQLResult.read(self)
#    1155 try:
# -> 1156     first_packet = self.connection._read_packet()
#    1158     if first_packet.is_ok_packet():
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/connections.py:725, in Connection._read_packet(self, packet_type)
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (1048, "Column 'SourceInfoID' cannot be null")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# File ~/vessels/eyened_platform/orm/eyened_orm/importer/importer.py:474, in Importer._import(self, data)
#     473 try:
# --> 474     self.session.commit()
#     476     # Write segmentation data
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/orm/session.py:2032, in Session.commit(self)
#    2030     trans = self._autobegin_t()
# -> 2032 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/orm/state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/orm/session.py:1313, in SessionTransaction.commit(self, _to_root)
#    1312     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1313         self._prepare_impl()
#    1315 if self._parent is None or self.nested:
#
# File <string>:2, in _prepare_impl(self)
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/orm/state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/orm/session.py:1288, in SessionTransaction._prepare_impl(self)
#    1287         break
# -> 1288     self.session.flush()
#    1289 else:
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/orm/session.py:4345, in Session.flush(self, objects)
#    4344     self._flushing = True
# -> 4345     self._flush(objects)
#    4346 finally:
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/orm/session.py:4480, in Session._flush(self, objects)
#    4479 except:
# -> 4480     with util.safe_reraise():
#    4481         transaction.rollback(_capture_exception=True)
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/orm/session.py:4441, in Session._flush(self, objects)
#    4440 try:
# -> 4441     flush_context.execute()
#    4442 finally:
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/orm/unitofwork.py:466, in UOWTransaction.execute(self)
#     465 for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466     rec.execute(self)
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/orm/unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/orm/persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)
#      90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)
#     119     ),
#     120 )
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/orm/persistence.py:1233, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1232 else:
# -> 1233     result = connection.execute(
#    1234         statement,
#    1235         params,
#    1236         execution_options=execution_options,
#    1237     )
#    1239 primary_key = result.inserted_primary_key
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/sql/elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)
#    1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/cursors.py:148, in Cursor.execute(self, query, args)
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/cursors.py:310, in Cursor._query(self, q)
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/connections.py:548, in Connection.query(self, sql, unbuffered)
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/connections.py:775, in Connection._read_query_result(self, unbuffered)
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/connections.py:1156, in MySQLResult.read(self)
#    1155 try:
# -> 1156     first_packet = self.connection._read_packet()
#    1158     if first_packet.is_ok_packet():
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/connections.py:725, in Connection._read_packet(self, packet_type)
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/.pyenv/versions/3.12.11/envs/rtnls/lib/python3.12/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1048, "Column 'SourceInfoID' cannot be null")
# [SQL: INSERT INTO `ImageInstance` (`SeriesID`, `SourceInfoID`, `DeviceInstanceID`, `ModalityID`, `ScanID`, `Modality`, `SOPInstanceUid`, `SOPClassUid`, `PhotometricInterpretation`, `SamplesPerPixel`, `Rows_y`, `Columns_x`, `NrOfFrames`, `SliceThickness`, `ResolutionAxial`, `ResolutionHorizontal`, `ResolutionVertical`, `HorizontalFieldOfView`, `Laterality`, `DICOMModality`, `AnatomicRegion`, `ETDRSField`, `Angiography`, `AcquisitionDateTime`, `PupilDilated`, `DatasetIdentifier`, `AltDatasetIdentifier`, `ThumbnailPath`, `OldPath`, `FDAIdentifier`, `Inactive`, `CFQuality`, `FileChecksum`, `DataHash`, `DateModified`, `DatePreprocessed`) VALUES (%(SeriesID)s, %(SourceInfoID)s, %(DeviceInstanceID)s, %(ModalityID)s, %(ScanID)s, %(Modality)s, %(SOPInstanceUid)s, %(SOPClassUid)s, %(PhotometricInterpretation)s, %(SamplesPerPixel)s, %(Rows_y)s, %(Columns_x)s, %(NrOfFrames)s, %(SliceThickness)s, %(ResolutionAxial)s, %(ResolutionHorizontal)s, %(ResolutionVertical)s, %(HorizontalFieldOfView)s, %(Laterality)s, %(DICOMModality)s, %(AnatomicRegion)s, %(ETDRSField)s, %(Angiography)s, %(AcquisitionDateTime)s, %(PupilDilated)s, %(DatasetIdentifier)s, %(AltDatasetIdentifier)s, %(ThumbnailPath)s, %(OldPath)s, %(FDAIdentifier)s, %(Inactive)s, %(CFQuality)s, %(FileChecksum)s, %(DataHash)s, %(DateModified)s, %(DatePreprocessed)s)]
# [parameters: {'SeriesID': 2026905, 'SourceInfoID': None, 'DeviceInstanceID': None, 'ModalityID': None, 'ScanID': None, 'Modality': None, 'SOPInstanceUid': None, 'SOPClassUid': None, 'PhotometricInterpretation': None, 'SamplesPerPixel': None, 'Rows_y': None, 'Columns_x': None, 'NrOfFrames': None, 'SliceThickness': None, 'ResolutionAxial': None, 'ResolutionHorizontal': None, 'ResolutionVertical': None, 'HorizontalFieldOfView': None, 'Laterality': None, 'DICOMModality': None, 'AnatomicRegion': None, 'ETDRSField': None, 'Angiography': None, 'AcquisitionDateTime': None, 'PupilDilated': None, 'DatasetIdentifier': 'eyened/public_data/av_segmentation/HRF_AV/images/15_g.jpg', 'AltDatasetIdentifier': None, 'ThumbnailPath': None, 'OldPath': '15_g', 'FDAIdentifier': None, 'Inactive': 0, 'CFQuality': None, 'FileChecksum': None, 'DataHash': None, 'DateModified': None, 'DatePreprocessed': None}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 importer.import_many(data)
#
# File ~/vessels/eyened_platform/orm/eyened_orm/importer/importer.py:641, in Importer.import_many(self, data, summary)
#     639         return self._summary(data)
#     640     else:
# --> 641         return self._import(data)
#     642 finally:
#     643     # Always clear collections at the end to ensure stateless behavior
#     644     self._clear_collections()
#
# File ~/vessels/eyened_platform/orm/eyened_orm/importer/importer.py:485, in Importer._import(self, data)
#     483 except Exception as e:
#     484     self.session.rollback()
# --> 485     raise RuntimeError(
#     486         "Failed to commit the transaction. Nothing will be written to the database and no files have been created or changed"
#     487     ) from e
#     489 self.post_insert()
#     490 # Save created images to return before clearing collections
#
# RuntimeError: Failed to commit the transaction. Nothing will be written to the database and no files have been created or changed

# %% [markdown]
# ### Inspect Results
#
# The project is now in the DB. We can easily generate a dataframe with image details to inspect results

# %%
# inspect the project using the ORM
from eyened_orm import Project


project = Project.by_name(session, 'FAU Fundus Dataset')

# %%
project.make_dataframe(session)

# %% [markdown]
# ### Updating existing projects
#
# Images can be inserted into existing projects, patients, studies and series by passing an existing project name, patient_identifier, study_date or series_id in the input structure. These will be matched to database entities (taking into account their nested structure).

# %%
# to simulate inserting into an existing project, we'll insert the same data again
# use create_patients=False, create_studies=False, create_series=False when inserting into existing objects to ensure that no new objects will be created
# copy_files=True will copy the files to a configurable directory
importer = Importer(
    session=session,
    config=config,
    run_ai_models=True, 
    generate_thumbnails=True,
    # copy_files=True # removed copy_files as it wasn't in __init__ signature I read
)

# Display a summary of what will be imported
import_summary = importer.import_many(data, summary=True)

# %%
importer.import_many(data)

# %%
project = Project.by_name(session, 'FAU Fundus Dataset')
project.make_dataframe(session)
