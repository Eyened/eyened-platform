# %% [markdown]
# ## Importer guide and examples
#
# The importer turns **flat rows** (`ImportRow`) into a consistent set of ORM entities:
#
# `Project → Patient → Study → Series → ImageInstance → ImageStorage` (+ device + storage backend)
#
# A typical workflow is:
#
# - Create a list of `ImportRow` objects (or load them from a CSV with `read_import_rows_csv`)
# - Call `plan_import(session, rows, ...)` to produce an `ImportRun`
# - Inspect the planned changes (`run.display_summary()` / `run.full_summary()`)
# - Apply them (`run.apply()` + `session.commit()`)
# - Optionally write the run to JSON (`run.write_json(...)`) and later load it (`ImportRun.read_json(...)`)
# - Optionally undo a completed run (`run.undo()` + commit)
#
# Notes:
#
# - `plan_import` may mutate ORM objects in-memory during planning; nothing is persisted until `run.apply()` and `commit()`.
# - `run.apply()` writes to the database but does not commit.

# %%
import json
from datetime import datetime
from pathlib import Path

from sqlalchemy import select, func
from sqlalchemy.orm import Session

from eyened_orm.importer import plan_import, ImportRow, ImportRun
from eyened_orm.importer.import_csv import read_import_rows_csv

from eyened_orm import (
    Project,
    Patient,
    Study,
    Series,
    ImageInstance,
    ImageStorage,
)

# Helper: creates an in-memory SQLite DB compatible with the EyeNED ORM schema.
from eyened_orm.utils.sqlite_testdb import create_sqlite_memory_sessionmaker

SessionLocal = create_sqlite_memory_sessionmaker(expire_on_commit=False)
print("Ready: in-memory database created")


def count(session: Session, model) -> int:
    return session.scalar(select(func.count()).select_from(model))


# Create a fresh session for the examples below.
session = SessionLocal()
print("Session ready")
# Out:
# Ready: in-memory database created
# Session ready

# %% [markdown]
# ## Load `ImportRow` records from a CSV
#
# If you already have your metadata in a CSV, you can load it directly into `ImportRow` objects and feed it into `plan_import`.
#
# The CSV header should use `ImportRow` field names (snake_case), for example: `project_name`, `patient_identifier`, `study_date`, `public_id`, `object_key`, ...

# %%
# Self-contained CSV example (write a tiny CSV, read it, import it)

csv_defaults = {
    "project_external": "Y",
    "manufacturer": "UNKOWN",
    "manufacturer_model_name": "UNKOWN",
    "device_description": "UNKOWN",
    "dataset_identifier": "",  # deprecated, but required by schema
    "storage_backend_kind": "local",
}

csv_path = Path("./_importer_output/example_rows.csv")
csv_path.parent.mkdir(exist_ok=True)

csv_path.write_text(
    "\n".join(
        [
            "project_name,storage_backend_key,object_key,patient_identifier,study_date,modality,laterality",
            "csv-proj,csv-backend,csv-0.png,patient-csv,2026-01-10,ColorFundus,L",
            "csv-proj,csv-backend,csv-1.png,patient-csv,2026-01-10,ColorFundus,R",
        ]
    )
    + "\n",
    encoding="utf-8",
)

rows_csv = read_import_rows_csv(csv_path)
print(f"Loaded {len(rows_csv)} rows from {csv_path}")

session_csv = SessionLocal()
run_csv = plan_import(session_csv, rows_csv, defaults=csv_defaults)
run_csv.display_summary()
run_csv.apply()
session_csv.commit()

print("Counts after CSV import:")
for model in [Project, Patient, Study, Series, ImageInstance, ImageStorage]:
    print(f"  {model.__name__:<15} : {count(session_csv, model)}")
# Out:
# Loaded 2 rows from _importer_output/example_rows.csv
# Import run: <strong>12e4c544fbd249278f3d8fa76e9deebd</strong> <br> Status: <strong>pending</strong> <br> Total changes: <strong>12</strong>
# <style>
# .eyened-wrapper {
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, sans-serif;
#     margin: 0.5rem 0 1rem 0;
# }
# .eyened-meta {
#     list-style: none;
#     margin: 0 0 0.75rem 0;
#     padding: 0.5rem 0.75rem;
#     border: 1px solid #ddd;
#     border-radius: 8px;
#     background: #fafafa;
# }
# .eyened-meta li {
#     margin: 0.15rem 0;
# }
# .eyened-table {
#     width: auto;
#     max-width: 100%;
#     border-collapse: collapse;
#     text-align: left;
# }
# .eyened-table th,
# .eyened-table td {
#     border: 1px solid #ddd;
#     padding: 4px 8px;
# }
# .eyened-table th {
#     background-color: #f3f3f3;
#     text-align: left;
#     font-weight: bold;
# }
# .eyened-table tr:nth-child(even) td {
#     background-color: #fafafa;
# }
# .eyened-table tr:hover td {
#     background-color: #eeeeee;
# }
# .eyened-table tr.separator td {
#     border: none;
#     padding: 0;
#     height: 3px;
#     background: black;
# }
# </style><div class="eyened-wrapper"><table class="eyened-table"><tr><th>Entity</th><th>Update</th><th>Create</th><th>Total</th></tr><tr><td>Series</td><td></td><td>2</td><td>2</td></tr><tr><td>ImageInstance</td><td></td><td>2</td><td>2</td></tr><tr><td>ImageStorage</td><td></td><td>2</td><td>2</td></tr><tr><td>StorageBackend</td><td></td><td>1</td><td>1</td></tr><tr><td>Project</td><td></td><td>1</td><td>1</td></tr><tr><td>DeviceModel</td><td></td><td>1</td><td>1</td></tr><tr><td>Patient</td><td></td><td>1</td><td>1</td></tr><tr><td>DeviceInstance</td><td></td><td>1</td><td>1</td></tr><tr><td>Study</td><td></td><td>1</td><td>1</td></tr></table></div>
# Counts after CSV import:
#   Project         : 1
#   Patient         : 1
#   Study           : 1
#   Series          : 2
#   ImageInstance   : 2
#   ImageStorage    : 2

# %% [markdown]
# ## Import new images (+ related entities)
#
# Typical case: you have new image files and want the importer to create (or reuse) the required hierarchy.
#
# We’ll build a few `ImportRow`, plan + review, then apply + commit.

# %%
defaults = {
    # Commonly required / convenient defaults
    "project_external": "Y",
    "manufacturer": "UNKOWN",
    "manufacturer_model_name": "UNKOWN",
    "device_description": "UNKOWN",
    "dataset_identifier": "",  # deprecated, but required by schema
    "storage_backend_kind": "local",
}

rows = [
    ImportRow(
        project_name="demo-project",
        storage_backend_key="demo-backend",
        object_key=f"demo-{i}.png",
        patient_identifier="patient-1",
        study_date=datetime.now().date(),
        modality="ColorFundus",
        laterality="L",
    )
    for i in range(2)
]

run = plan_import(session, rows, defaults=defaults)
run.display_summary()

run.apply()
session.commit()

print("Counts after import:")
for model in [Project, Patient, Study, Series, ImageInstance, ImageStorage]:
    print(f"  {model.__name__:<15} : {count(session, model)}")
# Out:
# Import run: <strong>3bc8a75c4b774b28a6738fd80dfbb78e</strong> <br> Status: <strong>pending</strong> <br> Total changes: <strong>10</strong>
# <style>
# .eyened-wrapper {
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, sans-serif;
#     margin: 0.5rem 0 1rem 0;
# }
# .eyened-meta {
#     list-style: none;
#     margin: 0 0 0.75rem 0;
#     padding: 0.5rem 0.75rem;
#     border: 1px solid #ddd;
#     border-radius: 8px;
#     background: #fafafa;
# }
# .eyened-meta li {
#     margin: 0.15rem 0;
# }
# .eyened-table {
#     width: auto;
#     max-width: 100%;
#     border-collapse: collapse;
#     text-align: left;
# }
# .eyened-table th,
# .eyened-table td {
#     border: 1px solid #ddd;
#     padding: 4px 8px;
# }
# .eyened-table th {
#     background-color: #f3f3f3;
#     text-align: left;
#     font-weight: bold;
# }
# .eyened-table tr:nth-child(even) td {
#     background-color: #fafafa;
# }
# .eyened-table tr:hover td {
#     background-color: #eeeeee;
# }
# .eyened-table tr.separator td {
#     border: none;
#     padding: 0;
#     height: 3px;
#     background: black;
# }
# </style><div class="eyened-wrapper"><table class="eyened-table"><tr><th>Entity</th><th>Update</th><th>Create</th><th>Total</th></tr><tr><td>Series</td><td></td><td>2</td><td>2</td></tr><tr><td>ImageInstance</td><td></td><td>2</td><td>2</td></tr><tr><td>ImageStorage</td><td></td><td>2</td><td>2</td></tr><tr><td>StorageBackend</td><td></td><td>1</td><td>1</td></tr><tr><td>Project</td><td></td><td>1</td><td>1</td></tr><tr><td>Patient</td><td></td><td>1</td><td>1</td></tr><tr><td>Study</td><td></td><td>1</td><td>1</td></tr></table></div>
# Counts after import:
#   Project         : 2
#   Patient         : 2
#   Study           : 2
#   Series          : 4
#   ImageInstance   : 4
#   ImageStorage    : 4

# %% [markdown]
# ### Example: attach to existing objects
#
# When part of the hierarchy already exists, you can attach to it by using either primary keys (`*_id`) or the usual lookup fields (e.g. `project_name` + `patient_identifier` + `study_date`).

# %%
rows = [
    ImportRow(
        project_name="demo-project",  # lookup existing project by name
        patient_identifier="patient-1",  # lookup existing patient by project_name + patient_identifier
        study_date=datetime.now().date(),  # lookup existing study by project_name + patient_identifier + study_date
        modality="ColorFundus",  # modality of new anonymous image
        laterality="L",  # laterality of new anonymous image
        storage_backend_key="demo-backend",  # lookup existing storage backend by key
        object_key=f"new_image.png",  # new image storage
    )
    for i in range(2)
]

run = plan_import(session, rows, defaults=defaults)
run.display_summary()

run.apply()
session.commit()

print("Counts after import:")
for model in [Project, Patient, Study, Series, ImageInstance, ImageStorage]:
    print(f"  {model.__name__:<15} : {count(session, model)}")
# Out:
# Import run: <strong>67410c4e8f4d42a4a7275802ba2e3a77</strong> <br> Status: <strong>pending</strong> <br> Total changes: <strong>3</strong>
# <style>
# .eyened-wrapper {
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, sans-serif;
#     margin: 0.5rem 0 1rem 0;
# }
# .eyened-meta {
#     list-style: none;
#     margin: 0 0 0.75rem 0;
#     padding: 0.5rem 0.75rem;
#     border: 1px solid #ddd;
#     border-radius: 8px;
#     background: #fafafa;
# }
# .eyened-meta li {
#     margin: 0.15rem 0;
# }
# .eyened-table {
#     width: auto;
#     max-width: 100%;
#     border-collapse: collapse;
#     text-align: left;
# }
# .eyened-table th,
# .eyened-table td {
#     border: 1px solid #ddd;
#     padding: 4px 8px;
# }
# .eyened-table th {
#     background-color: #f3f3f3;
#     text-align: left;
#     font-weight: bold;
# }
# .eyened-table tr:nth-child(even) td {
#     background-color: #fafafa;
# }
# .eyened-table tr:hover td {
#     background-color: #eeeeee;
# }
# .eyened-table tr.separator td {
#     border: none;
#     padding: 0;
#     height: 3px;
#     background: black;
# }
# </style><div class="eyened-wrapper"><table class="eyened-table"><tr><th>Entity</th><th>Update</th><th>Create</th><th>Total</th></tr><tr><td>Series</td><td></td><td>1</td><td>1</td></tr><tr><td>ImageInstance</td><td></td><td>1</td><td>1</td></tr><tr><td>ImageStorage</td><td></td><td>1</td><td>1</td></tr></table></div>
# Counts after import:
#   Project         : 2
#   Patient         : 2
#   Study           : 2
#   Series          : 5
#   ImageInstance   : 5
#   ImageStorage    : 5

# %% [markdown]
# ### Example: group images into the same Series with `series_anonymous_identity`
#
# Sometimes you don’t know the real lookup key for an entity (e.g. no `series_instance_uid`). The importer supports *batch-local grouping* via `*_anonymous_identity` fields.
# For example, rows with the same `series_anonymous_identity` will be grouped into the **same `Series`**
#
# This is useful when you only know that a set of images belong together, but you don’t have stable DICOM identifiers.
#
# Below we import 3 images with **no `series_instance_uid`**. By setting the same `series_anonymous_identity`, they will be created under **one shared `Series`**.

# %%
rows_grouped = [
    ImportRow(
        project_name="anon-series-proj",
        project_external="Y",
        dataset_identifier="",
        patient_identifier="p1",
        study_date=datetime.now().date(),
        storage_backend_key="sb",
        storage_backend_kind="test-kind",
        object_key=f"anon-series-{i}.png",
        series_anonymous_identity=1,  # same => same Series
        manufacturer="m",
        manufacturer_model_name="mm",
        device_description="d",
    )
    for i in range(3)
]

run_group = plan_import(session, rows_grouped)
run_group.display_summary()

run_group.apply()
session.commit()

print("Counts after import:")
for model in [Project, Patient, Study, Series, ImageInstance, ImageStorage]:
    print(f"  {model.__name__:<15} : {count(session, model)}")
# Out:
# Import run: <strong>3661e7eb6f524c0d9b775d3c1292460a</strong> <br> Status: <strong>pending</strong> <br> Total changes: <strong>13</strong>
# <style>
# .eyened-wrapper {
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, sans-serif;
#     margin: 0.5rem 0 1rem 0;
# }
# .eyened-meta {
#     list-style: none;
#     margin: 0 0 0.75rem 0;
#     padding: 0.5rem 0.75rem;
#     border: 1px solid #ddd;
#     border-radius: 8px;
#     background: #fafafa;
# }
# .eyened-meta li {
#     margin: 0.15rem 0;
# }
# .eyened-table {
#     width: auto;
#     max-width: 100%;
#     border-collapse: collapse;
#     text-align: left;
# }
# .eyened-table th,
# .eyened-table td {
#     border: 1px solid #ddd;
#     padding: 4px 8px;
# }
# .eyened-table th {
#     background-color: #f3f3f3;
#     text-align: left;
#     font-weight: bold;
# }
# .eyened-table tr:nth-child(even) td {
#     background-color: #fafafa;
# }
# .eyened-table tr:hover td {
#     background-color: #eeeeee;
# }
# .eyened-table tr.separator td {
#     border: none;
#     padding: 0;
#     height: 3px;
#     background: black;
# }
# </style><div class="eyened-wrapper"><table class="eyened-table"><tr><th>Entity</th><th>Update</th><th>Create</th><th>Total</th></tr><tr><td>ImageInstance</td><td></td><td>3</td><td>3</td></tr><tr><td>ImageStorage</td><td></td><td>3</td><td>3</td></tr><tr><td>StorageBackend</td><td></td><td>1</td><td>1</td></tr><tr><td>Project</td><td></td><td>1</td><td>1</td></tr><tr><td>DeviceModel</td><td></td><td>1</td><td>1</td></tr><tr><td>Patient</td><td></td><td>1</td><td>1</td></tr><tr><td>DeviceInstance</td><td></td><td>1</td><td>1</td></tr><tr><td>Study</td><td></td><td>1</td><td>1</td></tr><tr><td>Series</td><td></td><td>1</td><td>1</td></tr></table></div>
# Counts after import:
#   Project         : 3
#   Patient         : 3
#   Study           : 3
#   Series          : 6
#   ImageInstance   : 8
#   ImageStorage    : 8

# %% [markdown]
# ### Print full change details
#
# If you want a per-entity/per-field view of what will be changed, use `run.full_summary()`.

# %%
print(run.full_summary())
# Out:
# Import run 67410c4e8f4d42a4a7275802ba2e3a77
# Status: done
# Change count: 3
# 1. CREATE Series (SeriesID=5)
#   Study : None -> Study (StudyID=2)
#
# 2. CREATE ImageInstance (ImageInstanceID=5)
#   Series            : None -> Series (SeriesID=5)
#   DeviceInstance    : None -> DeviceInstance (DeviceInstanceID=1)
#   Modality          : None -> Modality.ColorFundus
#   Laterality        : None -> Laterality.L
#   DatasetIdentifier : None ->
#
# 3. CREATE ImageStorage (ImageStorageID=5)
#   StorageBackend : None -> StorageBackend (StorageBackendID=2)
#   ImageInstance  : None -> ImageInstance (ImageInstanceID=5)
#   ObjectKey      : None -> new_image.png
#   Format         : None -> image/png

# %% [markdown]
# ## Write an import run to JSON
#
# After applying successfully (`run.status == "done"`), you can write the run to JSON.
#
# This JSON is meant for **audit/undo**: it stores entity references by primary key.

# %%
out_dir = Path("./_importer_output")
out_dir.mkdir(exist_ok=True)
json_path = out_dir / "import_run.json"

run.write_json(json_path)
print("Wrote:", json_path)

# Inspect the file (optional)
print(json.dumps(run.to_dict(), indent=2)[:800] + "\n...")
# Out:
# Wrote: _importer_output/import_run.json
# {
#   "import_run_id": "67410c4e8f4d42a4a7275802ba2e3a77",
#   "status": "done",
#   "changes": [
#     {
#       "type": "create",
#       "entity": {
#         "type": "entity",
#         "entity_model": "Series",
#         "primary_key": {
#           "SeriesID": 5
#         }
#       },
#       "updates": {
#         "Study": {
#           "old_value": {
#             "type": "value",
#             "value": null
#           },
#           "new_value": {
#             "type": "entity",
#             "entity_model": "Study",
#             "primary_key": {
#               "StudyID": 2
#             }
#           }
#         }
#       }
#     },
#     {
#       "type": "create",
#       "entity": {
#         "type": "entity",
#         "entity_model": "ImageInstance",
#         "primary_key": {
#           "ImageInstanceID": 5
#         }
#       },
#       "updat
# ...

# %% [markdown]
# ## Undo an import run (including from a new session)
#
# Undo is often performed later and/or in a different process. The JSON format supports this by resolving entities by primary key.

# %%
# Close the current session and open a new one to simulate a separate process.
session.close()
session = SessionLocal()

loaded = ImportRun.read_json(session, json_path)
loaded.display_summary()

print("Counts before undo:")
print("  Project      ", count(session, Project))
print("  Series       ", count(session, Series))
print("  ImageInstance", count(session, ImageInstance))
print("  ImageStorage ", count(session, ImageStorage))

loaded.undo()
session.commit()

print("Counts after undo:")
print("  Project      ", count(session, Project))
print("  Series       ", count(session, Series))
print("  ImageInstance", count(session, ImageInstance))
print("  ImageStorage ", count(session, ImageStorage))
# Out:
# Import run: <strong>67410c4e8f4d42a4a7275802ba2e3a77</strong> <br> Status: <strong>done</strong> <br> Total changes: <strong>3</strong>
# <style>
# .eyened-wrapper {
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, sans-serif;
#     margin: 0.5rem 0 1rem 0;
# }
# .eyened-meta {
#     list-style: none;
#     margin: 0 0 0.75rem 0;
#     padding: 0.5rem 0.75rem;
#     border: 1px solid #ddd;
#     border-radius: 8px;
#     background: #fafafa;
# }
# .eyened-meta li {
#     margin: 0.15rem 0;
# }
# .eyened-table {
#     width: auto;
#     max-width: 100%;
#     border-collapse: collapse;
#     text-align: left;
# }
# .eyened-table th,
# .eyened-table td {
#     border: 1px solid #ddd;
#     padding: 4px 8px;
# }
# .eyened-table th {
#     background-color: #f3f3f3;
#     text-align: left;
#     font-weight: bold;
# }
# .eyened-table tr:nth-child(even) td {
#     background-color: #fafafa;
# }
# .eyened-table tr:hover td {
#     background-color: #eeeeee;
# }
# .eyened-table tr.separator td {
#     border: none;
#     padding: 0;
#     height: 3px;
#     background: black;
# }
# </style><div class="eyened-wrapper"><table class="eyened-table"><tr><th>Entity</th><th>Update</th><th>Create</th><th>Total</th></tr><tr><td>Series</td><td></td><td>1</td><td>1</td></tr><tr><td>ImageInstance</td><td></td><td>1</td><td>1</td></tr><tr><td>ImageStorage</td><td></td><td>1</td><td>1</td></tr></table></div>
# Counts before undo:
#   Project       3
#   Series        6
#   ImageInstance 8
#   ImageStorage  8
# Counts after undo:
#   Project       3
#   Series        5
#   ImageInstance 7
#   ImageStorage  7

# %% [markdown]
# ## Special use cases

# %% [markdown]
# ### Add only a Project or a Patient
#
# You don’t need any image fields if you only want to create/patch higher-level entities.
#
# - **Project only**: provide `project_name` (and any project fields)
# - **Project + Patient**: add `patient_identifier`

# %%
# Project + Patient only
s2 = SessionLocal()

run_pp = plan_import(
    s2,
    [
        ImportRow(
            project_name="pp-proj", project_external="Y", patient_identifier="pat-1"
        )
    ],
)
run_pp.display_summary()
run_pp.apply()
s2.commit()

print("Counts:")
print("  Project ", count(s2, Project))
print("  Patient ", count(s2, Patient))
print("  Study   ", count(s2, Study))
print("  Storage ", count(s2, ImageStorage))
# Out:
# Import run: <strong>024222ed4acf42eaa39cfe016630b2bd</strong> <br> Status: <strong>pending</strong> <br> Total changes: <strong>2</strong>
# <style>
# .eyened-wrapper {
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, sans-serif;
#     margin: 0.5rem 0 1rem 0;
# }
# .eyened-meta {
#     list-style: none;
#     margin: 0 0 0.75rem 0;
#     padding: 0.5rem 0.75rem;
#     border: 1px solid #ddd;
#     border-radius: 8px;
#     background: #fafafa;
# }
# .eyened-meta li {
#     margin: 0.15rem 0;
# }
# .eyened-table {
#     width: auto;
#     max-width: 100%;
#     border-collapse: collapse;
#     text-align: left;
# }
# .eyened-table th,
# .eyened-table td {
#     border: 1px solid #ddd;
#     padding: 4px 8px;
# }
# .eyened-table th {
#     background-color: #f3f3f3;
#     text-align: left;
#     font-weight: bold;
# }
# .eyened-table tr:nth-child(even) td {
#     background-color: #fafafa;
# }
# .eyened-table tr:hover td {
#     background-color: #eeeeee;
# }
# .eyened-table tr.separator td {
#     border: none;
#     padding: 0;
#     height: 3px;
#     background: black;
# }
# </style><div class="eyened-wrapper"><table class="eyened-table"><tr><th>Entity</th><th>Update</th><th>Create</th><th>Total</th></tr><tr><td>Project</td><td></td><td>1</td><td>1</td></tr><tr><td>Patient</td><td></td><td>1</td><td>1</td></tr></table></div>
# Counts:
#   Project  4
#   Patient  4
#   Study    3
#   Storage  7

# %% [markdown]
# ### Update existing entities
#
# You can update an entity by importing a row that resolves to the existing entity (lookup or primary key) and providing fields to change.
#
# Example: import a `Project`, then update its description.

# %%
# Fresh DB again for a clean example
SessionLocal2 = create_sqlite_memory_sessionmaker(expire_on_commit=False)

s = SessionLocal2()

run1 = plan_import(
    s,
    [
        ImportRow(
            project_name="proj-only",
            project_external="Y",
            project_description="initial",
        )
    ],
)
run1.display_summary()
run1.apply()
s.commit()

run2 = plan_import(
    s,
    [ImportRow(project_name="proj-only", project_description="updated")],
)
run2.display_summary()
run2.apply()
s.commit()
print(run2.full_summary())

proj = s.scalar(select(Project))
print("Project:", proj.ProjectID, proj.ProjectName, proj.Description)
# Out:
# Import run: <strong>ceb5e8d9c2aa4609b2f7012361f87a46</strong> <br> Status: <strong>pending</strong> <br> Total changes: <strong>1</strong>
# <style>
# .eyened-wrapper {
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, sans-serif;
#     margin: 0.5rem 0 1rem 0;
# }
# .eyened-meta {
#     list-style: none;
#     margin: 0 0 0.75rem 0;
#     padding: 0.5rem 0.75rem;
#     border: 1px solid #ddd;
#     border-radius: 8px;
#     background: #fafafa;
# }
# .eyened-meta li {
#     margin: 0.15rem 0;
# }
# .eyened-table {
#     width: auto;
#     max-width: 100%;
#     border-collapse: collapse;
#     text-align: left;
# }
# .eyened-table th,
# .eyened-table td {
#     border: 1px solid #ddd;
#     padding: 4px 8px;
# }
# .eyened-table th {
#     background-color: #f3f3f3;
#     text-align: left;
#     font-weight: bold;
# }
# .eyened-table tr:nth-child(even) td {
#     background-color: #fafafa;
# }
# .eyened-table tr:hover td {
#     background-color: #eeeeee;
# }
# .eyened-table tr.separator td {
#     border: none;
#     padding: 0;
#     height: 3px;
#     background: black;
# }
# </style><div class="eyened-wrapper"><table class="eyened-table"><tr><th>Entity</th><th>Update</th><th>Create</th><th>Total</th></tr><tr><td>Project</td><td></td><td>1</td><td>1</td></tr></table></div>
# Import run: <strong>75bae014f2254ed5acc5a0b22c997d92</strong> <br> Status: <strong>pending</strong> <br> Total changes: <strong>1</strong>
# <style>
# .eyened-wrapper {
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, sans-serif;
#     margin: 0.5rem 0 1rem 0;
# }
# .eyened-meta {
#     list-style: none;
#     margin: 0 0 0.75rem 0;
#     padding: 0.5rem 0.75rem;
#     border: 1px solid #ddd;
#     border-radius: 8px;
#     background: #fafafa;
# }
# .eyened-meta li {
#     margin: 0.15rem 0;
# }
# .eyened-table {
#     width: auto;
#     max-width: 100%;
#     border-collapse: collapse;
#     text-align: left;
# }
# .eyened-table th,
# .eyened-table td {
#     border: 1px solid #ddd;
#     padding: 4px 8px;
# }
# .eyened-table th {
#     background-color: #f3f3f3;
#     text-align: left;
#     font-weight: bold;
# }
# .eyened-table tr:nth-child(even) td {
#     background-color: #fafafa;
# }
# .eyened-table tr:hover td {
#     background-color: #eeeeee;
# }
# .eyened-table tr.separator td {
#     border: none;
#     padding: 0;
#     height: 3px;
#     background: black;
# }
# </style><div class="eyened-wrapper"><table class="eyened-table"><tr><th>Entity</th><th>Update</th><th>Create</th><th>Total</th></tr><tr><td>Project</td><td>1</td><td></td><td>1</td></tr></table></div>
# Import run 75bae014f2254ed5acc5a0b22c997d92
# Status: done
# Change count: 1
# 1. UPDATE Project (ProjectID=1)
#   Description : initial -> updated
#
# Project: 1 proj-only updated

# %% [markdown]
# ### Update laterality for a few images (identified by `public_id`)
#
# This is a good fit for the importer: `ImageInstance` can be resolved by `public_id`, and `Laterality` is mutable.
#
# For patching, you only need enough identity to resolve the existing entity (`public_id`) plus the fields you want to change (`laterality`).

# %%
# 1) Create a few images
rows_seed = [
    ImportRow(
        project_name="lat-proj",
        storage_backend_key="sb-lat",
        object_key=f"lat-{i}.png",
        patient_identifier="pat-lat",
        study_date=datetime(2026, 2, 1).date(),
        modality="ColorFundus",
        laterality="L",
    )
    for i in range(3)
]

run_seed = plan_import(session, rows_seed, defaults=defaults)
run_seed.display_summary()
run_seed.apply()
session.commit()

print(">>> Before patch")
images = ImageInstance.fetch_all(session)
for im in images:
    print(im.PublicID, im.Laterality)

# 2) Patch laterality by PublicID (no need to restate the whole hierarchy)
rows_patch = [ImportRow(public_id=im.PublicID, laterality="R") for im in images[:5]]

run_patch = plan_import(session, rows_patch)
run_patch.display_summary()
print(run_patch.full_summary())

run_patch.apply()
session.commit()

print(">>> After patch")
for im in ImageInstance.fetch_all(session):
    print(im.PublicID, im.Laterality)
# Out:
# Import run: <strong>e5ffa8f146b7496aa2e568cd696d7351</strong> <br> Status: <strong>pending</strong> <br> Total changes: <strong>13</strong>
# <style>
# .eyened-wrapper {
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, sans-serif;
#     margin: 0.5rem 0 1rem 0;
# }
# .eyened-meta {
#     list-style: none;
#     margin: 0 0 0.75rem 0;
#     padding: 0.5rem 0.75rem;
#     border: 1px solid #ddd;
#     border-radius: 8px;
#     background: #fafafa;
# }
# .eyened-meta li {
#     margin: 0.15rem 0;
# }
# .eyened-table {
#     width: auto;
#     max-width: 100%;
#     border-collapse: collapse;
#     text-align: left;
# }
# .eyened-table th,
# .eyened-table td {
#     border: 1px solid #ddd;
#     padding: 4px 8px;
# }
# .eyened-table th {
#     background-color: #f3f3f3;
#     text-align: left;
#     font-weight: bold;
# }
# .eyened-table tr:nth-child(even) td {
#     background-color: #fafafa;
# }
# .eyened-table tr:hover td {
#     background-color: #eeeeee;
# }
# .eyened-table tr.separator td {
#     border: none;
#     padding: 0;
#     height: 3px;
#     background: black;
# }
# </style><div class="eyened-wrapper"><table class="eyened-table"><tr><th>Entity</th><th>Update</th><th>Create</th><th>Total</th></tr><tr><td>Series</td><td></td><td>3</td><td>3</td></tr><tr><td>ImageInstance</td><td></td><td>3</td><td>3</td></tr><tr><td>ImageStorage</td><td></td><td>3</td><td>3</td></tr><tr><td>StorageBackend</td><td></td><td>1</td><td>1</td></tr><tr><td>Project</td><td></td><td>1</td><td>1</td></tr><tr><td>Patient</td><td></td><td>1</td><td>1</td></tr><tr><td>Study</td><td></td><td>1</td><td>1</td></tr></table></div>
# >>> Before patch
# 2qzro8rdvp22 Laterality.L
# 59jgrcpswhen Laterality.R
# vyp55w6cgs6s Laterality.L
# pa7bywm946bg Laterality.L
# tloaxkeynd3h None
# 4c4dj6v7d9vk None
# hn6qtdb1yn40 None
# izg8jnri6fth Laterality.L
# 5p0ctvgg6d7e Laterality.L
# udq6il8caaax Laterality.L
# Import run: <strong>82118aaeb66343ff85c34c8b9f1dc909</strong> <br> Status: <strong>pending</strong> <br> Total changes: <strong>4</strong>
# <style>
# .eyened-wrapper {
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, sans-serif;
#     margin: 0.5rem 0 1rem 0;
# }
# .eyened-meta {
#     list-style: none;
#     margin: 0 0 0.75rem 0;
#     padding: 0.5rem 0.75rem;
#     border: 1px solid #ddd;
#     border-radius: 8px;
#     background: #fafafa;
# }
# .eyened-meta li {
#     margin: 0.15rem 0;
# }
# .eyened-table {
#     width: auto;
#     max-width: 100%;
#     border-collapse: collapse;
#     text-align: left;
# }
# .eyened-table th,
# .eyened-table td {
#     border: 1px solid #ddd;
#     padding: 4px 8px;
# }
# .eyened-table th {
#     background-color: #f3f3f3;
#     text-align: left;
#     font-weight: bold;
# }
# .eyened-table tr:nth-child(even) td {
#     background-color: #fafafa;
# }
# .eyened-table tr:hover td {
#     background-color: #eeeeee;
# }
# .eyened-table tr.separator td {
#     border: none;
#     padding: 0;
#     height: 3px;
#     background: black;
# }
# </style><div class="eyened-wrapper"><table class="eyened-table"><tr><th>Entity</th><th>Update</th><th>Create</th><th>Total</th></tr><tr><td>ImageInstance</td><td>4</td><td></td><td>4</td></tr></table></div>
# Import run 82118aaeb66343ff85c34c8b9f1dc909
# Status: pending
# Change count: 4
# 1. UPDATE ImageInstance (ImageInstanceID=1)
#   Laterality : Laterality.L -> Laterality.R
#
# 2. UPDATE ImageInstance (ImageInstanceID=3)
#   Laterality : Laterality.L -> Laterality.R
#
# 3. UPDATE ImageInstance (ImageInstanceID=4)
#   Laterality : Laterality.L -> Laterality.R
#
# 4. UPDATE ImageInstance (ImageInstanceID=6)
#   Laterality : None -> Laterality.R
#
# >>> After patch
# 2qzro8rdvp22 Laterality.R
# 59jgrcpswhen Laterality.R
# vyp55w6cgs6s Laterality.R
# pa7bywm946bg Laterality.R
# tloaxkeynd3h Laterality.R
# 4c4dj6v7d9vk None
# hn6qtdb1yn40 None
# izg8jnri6fth Laterality.L
# 5p0ctvgg6d7e Laterality.L
# udq6il8caaax Laterality.L

# %% [markdown]
# ### Other behaviors worth knowing (covered by tests)
#
# - **Reject early**: missing required parent chain (e.g. no project identity) fails during planning.
# - **Deduplication**: rows with the same lookup key are merged into one create + updates.
# - **Idempotency**: re-running the same import should not produce any changes.
# - **Primary-key precedence**: if `*_id` is provided, it wins over lookup keys (and allows renaming lookup fields).
#
# See the unit tests under `orm/tests/` for concrete examples.
